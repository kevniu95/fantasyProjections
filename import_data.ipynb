# %%
import re
import pickle
import requests
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Dictionary mapping fantasydata.com team abbreviations to pro-football-reference team abbreviations
adp_to_pfr = {'ARI':'ARI','ATL':'ATL','BAL':'BAL','BUF':'BUF','CAR':'CAR',
                'CHI':'CHI','CIN':'CIN','CLE':'CLE','DAL':'DAL','DEN':'DEN',
                'DET':'DET','GB':'GNB','HOU':'HOU','IND':'IND','JAX':'JAX',
                'KC':'KAN','LAC':'LAC','LAR':'LAR','LV':'LVR','MIA':'MIA',
                'MIN':'MIN','NO':'NOR','NE':'NWE','NYG':'NYG','NYJ':'NYJ',
                'PHI':'PHI','PIT':'PIT','SEA':'SEA','SF':'SFO','TB':'TAM',
                'TEN':'TEN','WAS':'WAS'}

# %%
# Source: https://fantasydata.com/nfl/adp - PPR
def import_adp_data(files_loc = './Data/historical_adp/'):
    df_dict = {}
    for i in range(2014, 2023):
        cols = ["Name", "Team", "Position", "PositionRank", "AverageDraftPositionPPR"]
        tmp= pd.read_csv(f'{files_loc}ppr-adp-{i}.csv',
                        usecols = cols)
        tmp['Year'] = i
        df_dict[i] = tmp
    return df_dict

def prep_adp_df(adp_data, adp_to_pfr):
    # Limit to only top 200 in ADP per year

    # 1. Concat
    adp_df = pd.concat(adp_data.values())
    # 2. Re-order columns
    adp_df = adp_df[['Name', 'Year', 'Team', 'Position', 'PositionRank', 'AverageDraftPositionPPR']]

    # 3. Get position rank as a number
    adp_df['PositionRank'] = adp_df['PositionRank'].str.extract('(\d+)')[0]
    
    # 4. Reset index
    adp_df.reset_index(inplace=True)
    adp_df.drop('index', axis = 1, inplace=True)
    # adp_df = adp_df.join(pd.get_dummies(adp_df['Position']))

    # 5. Remove III's from end of names
    adp_df['Name'] = adp_df['Name'].str.replace('([I ]+$)', '',regex= True)
    adp_df['Name'] = adp_df['Name'].str.replace('CJ ', 'C.J. ')
    adp_df['Name'] = adp_df['Name'].str.replace('DJ ', 'D.J. ')
    adp_df['Name'] = adp_df['Name'].str.replace('DK ', 'D.K. ')
    adp_df['Name'] = adp_df['Name'].str.replace('Steve Smith', 'Steve Smith Sr.')
    adp_df['Name'] = adp_df['Name'].str.replace('Marvin Jones Jr.', 'Marvin Jones', regex = False)
    adp_df['Name'] = adp_df['Name'].str.replace('Darrell Henderson Jr.', 'Darrell Henderson', regex = False)
    adp_df['Name'] = adp_df['Name'].str.replace('Gabe Davis', 'Gabriel Davis')
    # adp_df = adp_df[adp_df['AverageDraftPositionPPR'] < 173].copy()
    # Changing to 170 to have consistent cutoff for position-based regression

    # 6. Limit to standard, relevant fantas positions
    adp_df = adp_df[adp_df['Position'].isin(['RB','WR','QB','WR','TE'])]

    # 7. Update team names for those teams that have moved in last 10 years
    adp_df['Team'] = adp_df['Team'].replace(adp_to_pfr) 
    adp_df.loc[(adp_df['Team'] == 'LVR') & (adp_df['Year'] <= 2019),'Team'] = 'OAK'
    adp_df.loc[(adp_df['Team'] == 'LAC') & (adp_df['Year'] <= 2016),'Team'] = 'SDG'
    adp_df.loc[(adp_df['Team'] == 'LAR') & (adp_df['Year'] <= 2015),'Team'] = 'STL'
    return adp_df

# %%
df_dict = import_adp_data()
adp_df = prep_adp_df(df_dict, adp_to_pfr)

with open('data/adp_info.p', 'wb') as handle:
    pickle.dump(adp_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Check col names same across years
def checkColNames(df_dict):
    a = None
    for k, v in df_dict.items():
        if a is None:
            a = list(v.columns)
        if list(v.columns) != a:
            print('There are some years where df columns have different names')

# Check Teams are correct
def checkTeamNames(df):
    test = df[['Team','Year']].drop_duplicates().sort_values(['Year','Team'])
    a = test.groupby(['Team'], as_index = False).min()[['Team','Year']]
    b = test.groupby(['Team'], as_index = False).max()[['Team','Year']]
    c = a.merge(b, on = 'Team')
    print(c[(c['Year_y'] - c['Year_x']) < 8])

checkColNames(df_dict)
# checkTeamNames(adp_df)

# %%
PFR_LINK = 'https://www.pro-football-reference.com/years/{yr}/fantasy.htm'

def player_info_from_link(link):
    info_dict = {'born' : None,
                    'draft': None,
                    'pos' : None}

    page = requests.get(link)
    if page.status_code == 200:
        soup = BeautifulSoup(page.content, 'html.parser')
    player_info  = soup.find_all('p')
    
    for info in player_info:
        if len(info.find_all('strong', text = 'Position')) > 0 :
            info_dict['pos'] = info.text.split(' ')[1].strip()[:2]
        if len(info.find_all('strong', text = 'Born:')) > 0 :
            dob = (info.text.replace('\n', ' ').replace('\xa0', ' '))
            dob = re.search('\w+\s\d{1,2},\s\d{4}', dob).group(0)
            info_dict['born'] = datetime.strptime(dob, '%B %d, %Y')
        if len(info.find_all('strong', text = 'Draft')) > 0:
            draft_info = info.text
            draft_pos = re.search('\([0-9]*', draft_info)
            try:
                info_dict['draft'] = int(draft_pos.group(0)[1:])
            except:
                pass

    return info_dict
        
# ID players by uniqe (name, position)
# Add to a dictionary containing their
    # 1. Birthdates
    # 2. NFL Draft Position
    # 3. Position
                    
def get_player_info(link = PFR_LINK):
    player_dict = {}
    for i in range(2013, 2022):
        use_link = link.format(yr = i)
        print(use_link)
        
        page = requests.get(use_link)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
        table = soup.find_all('table', id = 'fantasy')
        players = table[0].find_all('tr')
        
        for player in players:
            atag = player.find_all('a')
            if len(atag) > 0:
                table_cols = player.find_all('td', class_="right")
                name = atag[0].text 
                position = table_cols[0].text
                if (name, position) not in player_dict:
                    print(f"Added {(name, position)} to dictionary")
                    player_link = 'https://www.pro-football-reference.com' + atag[0]['href']
                    info = player_info_from_link(player_link)
                    print(info)
                    player_dict[name, position] = info
    return player_dict
            
player_dict = get_player_info()
with open('data/pfr_player_info.p', 'wb') as handle:
    pickle.dump(player_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# https://www.pro-football-reference.com/years/2013/fantasy.htm
# Added ('Jamaal Charles', 'RB') to dictionary
# {'born': datetime.datetime(1986, 12, 27, 0, 0), 'draft': 73, 'pos': 'RB'}
# Added ('LeSean McCoy', 'RB') to dictionary
# {'born': datetime.datetime(1988, 7, 12, 0, 0), 'draft': 53, 'pos': 'RB'}
# Added ('Peyton Manning', 'QB') to dictionary
# {'born': datetime.datetime(1976, 3, 24, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Matt Forte', 'RB') to dictionary
# {'born': datetime.datetime(1985, 12, 10, 0, 0), 'draft': 44, 'pos': 'RB'}
# Added ('Jimmy Graham', 'TE') to dictionary
# {'born': datetime.datetime(1986, 11, 24, 0, 0), 'draft': 95, 'pos': 'TE'}
# Added ('Marshawn Lynch', 'RB') to dictionary
# {'born': datetime.datetime(1986, 4, 22, 0, 0), 'draft': 12, 'pos': 'RB'}
# Added ('Knowshon Moreno', 'RB') to dictionary
# {'born': datetime.datetime(1987, 7, 16, 0, 0), 'draft': 12, 'pos': 'RB'}
# Added ('Josh Gordon', 'WR') to dictionary
# {'born': datetime.datetime(1991, 4, 13, 0, 0), 'draft': 1, 'pos': 'WR'}
# Added ('Demaryius Thomas', 'WR') to dictionary
# {'born': datetime.datetime(1987, 12, 25, 0, 0), 'draft': 22, 'pos': 'WR'}
# Added ('Calvin Johnson', 'WR') to dictionary
# {'born': datetime.datetime(1985, 9, 29, 0, 0), 'draft': 2, 'pos': 'WR'}
# Added ('Drew Brees', 'QB') to dictionary
# {'born': datetime.datetime(1979, 1, 15, 0, 0), 'draft': 32, 'pos': 'QB'}
# Added ('A.J. Green', 'WR') to dictionary
# {'born': datetime.datetime(1988, 7, 31, 0, 0), 'draft': 4, 'pos': 'WR'}
# Added ('Brandon Marshall', 'WR') to dictionary
# {'born': datetime.datetime(1984, 3, 23, 0, 0), 'draft': 119, 'pos': 'WR'}
# Added ('Antonio Brown', 'WR') to dictionary
# {'born': datetime.datetime(1988, 7, 10, 0, 0), 'draft': 195, 'pos': 'WR'}
# Added ('Eddie Lacy', 'RB') to dictionary
# {'born': datetime.datetime(1990, 6, 2, 0, 0), 'draft': 61, 'pos': 'RB'}
# Added ('Dez Bryant', 'WR') to dictionary
# {'born': datetime.datetime(1988, 11, 4, 0, 0), 'draft': 24, 'pos': 'WR'}
# Added ('DeMarco Murray', 'RB') to dictionary
# {'born': datetime.datetime(1988, 2, 12, 0, 0), 'draft': 71, 'pos': 'RB'}
# Added ('Adrian Peterson', 'RB') to dictionary
# {'born': datetime.datetime(1985, 3, 21, 0, 0), 'draft': 7, 'pos': 'RB'}
# Added ('Alshon Jeffery', 'WR') to dictionary
# {'born': datetime.datetime(1990, 2, 14, 0, 0), 'draft': 45, 'pos': 'WR'}
# Added ('Eric Decker', 'WR') to dictionary
# {'born': datetime.datetime(1987, 3, 15, 0, 0), 'draft': 87, 'pos': 'WR'}
# Added ('Chris Johnson', 'RB') to dictionary
# {'born': datetime.datetime(1985, 9, 23, 0, 0), 'draft': 24, 'pos': 'RB'}
# Added ('Vernon Davis', 'TE') to dictionary
# {'born': datetime.datetime(1984, 1, 31, 0, 0), 'draft': 6, 'pos': 'TE'}
# Added ('DeSean Jackson', 'WR') to dictionary
# {'born': datetime.datetime(1986, 12, 1, 0, 0), 'draft': 49, 'pos': 'WR'}
# Added ('Fred Jackson', 'RB') to dictionary
# {'born': datetime.datetime(1981, 2, 20, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jordy Nelson', 'WR') to dictionary
# {'born': datetime.datetime(1985, 5, 31, 0, 0), 'draft': 36, 'pos': 'WR'}
# Added ('Reggie Bush', 'RB') to dictionary
# {'born': datetime.datetime(1985, 3, 2, 0, 0), 'draft': 2, 'pos': 'RB'}
# Added ('Ryan Mathews', 'RB') to dictionary
# {'born': datetime.datetime(1987, 10, 10, 0, 0), 'draft': 12, 'pos': 'RB'}
# Added ('Julius Thomas', 'TE') to dictionary
# {'born': datetime.datetime(1988, 6, 27, 0, 0), 'draft': 129, 'pos': 'TE'}
# Added ('Andre Johnson', 'WR') to dictionary
# {'born': datetime.datetime(1981, 7, 11, 0, 0), 'draft': 3, 'pos': 'WR'}
# Added ('Frank Gore', 'RB') to dictionary
# {'born': datetime.datetime(1983, 5, 14, 0, 0), 'draft': 65, 'pos': 'RB'}
# Added ("Le'Veon Bell", 'RB') to dictionary
# {'born': datetime.datetime(1992, 2, 18, 0, 0), 'draft': 48, 'pos': 'RB'}
# Added ('Pierre Garcon', 'WR') to dictionary
# {'born': datetime.datetime(1986, 8, 8, 0, 0), 'draft': 205, 'pos': 'WR'}
# Added ('Vincent Jackson', 'WR') to dictionary
# {'born': datetime.datetime(1983, 1, 14, 0, 0), 'draft': 61, 'pos': 'WR'}
# Added ('Alfred Morris', 'RB') to dictionary
# {'born': datetime.datetime(1988, 12, 12, 0, 0), 'draft': 173, 'pos': 'RB'}
# Added ('Tony Gonzalez', 'TE') to dictionary
# {'born': datetime.datetime(1976, 2, 27, 0, 0), 'draft': 13, 'pos': 'TE'}
# Added ('Anquan Boldin', 'WR') to dictionary
# {'born': datetime.datetime(1980, 10, 3, 0, 0), 'draft': 54, 'pos': 'WR'}
# Added ('Giovani Bernard', 'RB') to dictionary
# {'born': datetime.datetime(1991, 11, 22, 0, 0), 'draft': 37, 'pos': 'RB'}
# Added ('Jordan Cameron', 'TE') to dictionary
# {'born': datetime.datetime(1988, 8, 7, 0, 0), 'draft': 102, 'pos': 'TE'}
# Added ('Jason Witten', 'TE') to dictionary
# {'born': datetime.datetime(1982, 5, 6, 0, 0), 'draft': 69, 'pos': 'TE'}
# Added ('Cam Newton', 'QB') to dictionary
# {'born': datetime.datetime(1989, 5, 11, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Joique Bell', 'RB') to dictionary
# {'born': datetime.datetime(1986, 8, 4, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Larry Fitzgerald', 'WR') to dictionary
# {'born': datetime.datetime(1983, 8, 31, 0, 0), 'draft': 3, 'pos': 'WR'}
# Added ('Andrew Luck', 'QB') to dictionary
# {'born': datetime.datetime(1989, 9, 12, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Zac Stacy', 'RB') to dictionary
# {'born': datetime.datetime(1991, 4, 9, 0, 0), 'draft': 160, 'pos': 'RB'}
# Added ('Andy Dalton', 'QB') to dictionary
# {'born': datetime.datetime(1987, 10, 29, 0, 0), 'draft': 35, 'pos': 'QB'}
# Added ('Keenan Allen', 'WR') to dictionary
# {'born': datetime.datetime(1992, 4, 27, 0, 0), 'draft': 76, 'pos': 'WR'}
# Added ('Philip Rivers', 'QB') to dictionary
# {'born': datetime.datetime(1981, 12, 8, 0, 0), 'draft': 4, 'pos': 'QB'}
# Added ('Julian Edelman', 'WR') to dictionary
# {'born': datetime.datetime(1986, 5, 22, 0, 0), 'draft': 232, 'pos': 'WR'}
# Added ('Charles Clay', 'TE') to dictionary
# {'born': datetime.datetime(1989, 2, 13, 0, 0), 'draft': 174, 'pos': 'TE'}
# Added ('Greg Olsen', 'TE') to dictionary
# {'born': datetime.datetime(1985, 3, 11, 0, 0), 'draft': 31, 'pos': 'TE'}
# Added ('Danny Woodhead', 'RB') to dictionary
# {'born': datetime.datetime(1985, 1, 25, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Matthew Stafford', 'QB') to dictionary
# {'born': datetime.datetime(1988, 2, 7, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('T.Y. Hilton', 'WR') to dictionary
# {'born': datetime.datetime(1989, 11, 14, 0, 0), 'draft': 92, 'pos': 'WR'}
# Added ('Torrey Smith', 'WR') to dictionary
# {'born': datetime.datetime(1989, 1, 26, 0, 0), 'draft': 58, 'pos': 'WR'}
# Added ('Marvin Jones', 'WR') to dictionary
# {'born': datetime.datetime(1990, 3, 12, 0, 0), 'draft': 166, 'pos': 'WR'}
# Added ('Maurice Jones-Drew', 'RB') to dictionary
# {'born': datetime.datetime(1985, 3, 23, 0, 0), 'draft': 60, 'pos': 'RB'}
# Added ('Riley Cooper', 'WR') to dictionary
# {'born': datetime.datetime(1987, 9, 9, 0, 0), 'draft': 159, 'pos': 'WR'}
# Added ('Wes Welker', 'WR') to dictionary
# {'born': datetime.datetime(1981, 5, 1, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Michael Floyd', 'WR') to dictionary
# {'born': datetime.datetime(1989, 11, 27, 0, 0), 'draft': 13, 'pos': 'WR'}
# Added ('Antonio Gates', 'TE') to dictionary
# {'born': datetime.datetime(1980, 6, 18, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Rashad Jennings', 'RB') to dictionary
# {'born': datetime.datetime(1985, 3, 26, 0, 0), 'draft': 250, 'pos': 'RB'}
# Added ('Russell Wilson', 'QB') to dictionary
# {'born': datetime.datetime(1988, 11, 29, 0, 0), 'draft': 75, 'pos': 'QB'}
# Added ('DeAngelo Williams', 'RB') to dictionary
# {'born': datetime.datetime(1983, 4, 25, 0, 0), 'draft': 27, 'pos': 'RB'}
# Added ('Martellus Bennett', 'TE') to dictionary
# {'born': datetime.datetime(1987, 3, 10, 0, 0), 'draft': 61, 'pos': 'TE'}
# Added ('Pierre Thomas', 'RB') to dictionary
# {'born': datetime.datetime(1984, 12, 18, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Mike Wallace', 'WR') to dictionary
# {'born': datetime.datetime(1986, 8, 1, 0, 0), 'draft': 84, 'pos': 'WR'}
# Added ('Brian Hartline', 'WR') to dictionary
# {'born': datetime.datetime(1986, 11, 22, 0, 0), 'draft': 108, 'pos': 'WR'}
# Added ('Colin Kaepernick', 'QB') to dictionary
# {'born': datetime.datetime(1987, 11, 3, 0, 0), 'draft': 36, 'pos': 'QB'}
# Added ('Marques Colston', 'WR') to dictionary
# {'born': datetime.datetime(1983, 6, 5, 0, 0), 'draft': 252, 'pos': 'WR'}
# Added ('Golden Tate', 'WR') to dictionary
# {'born': datetime.datetime(1988, 8, 2, 0, 0), 'draft': 60, 'pos': 'WR'}
# Added ('Tony Romo', 'QB') to dictionary
# {'born': datetime.datetime(1980, 4, 21, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Jared Cook', 'TE') to dictionary
# {'born': datetime.datetime(1987, 4, 7, 0, 0), 'draft': 89, 'pos': 'TE'}
# Added ('Victor Cruz', 'WR') to dictionary
# {'born': datetime.datetime(1986, 11, 11, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Nick Foles ', 'QB') to dictionary
# {'born': datetime.datetime(1989, 1, 20, 0, 0), 'draft': 88, 'pos': 'QB'}
# Added ('Delanie Walker', 'TE') to dictionary
# {'born': datetime.datetime(1984, 8, 12, 0, 0), 'draft': 175, 'pos': 'TE'}
# Added ('Kyle Juszczyk', '') to dictionary
# {'born': datetime.datetime(1991, 4, 23, 0, 0), 'draft': 130, 'pos': 'FB'}
# Added ('Andre Ellington', 'RB') to dictionary
# {'born': datetime.datetime(1989, 2, 3, 0, 0), 'draft': 187, 'pos': 'RB'}
# Added ('Kendall Wright', 'WR') to dictionary
# {'born': datetime.datetime(1989, 11, 12, 0, 0), 'draft': 20, 'pos': 'WR'}
# Added ('Ben Roethlisberger', 'QB') to dictionary
# {'born': datetime.datetime(1982, 3, 2, 0, 0), 'draft': 11, 'pos': 'QB'}
# Added ('Alex Smith', 'QB') to dictionary
# {'born': datetime.datetime(1984, 5, 7, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Tom Brady', 'QB') to dictionary
# {'born': datetime.datetime(1977, 8, 3, 0, 0), 'draft': 199, 'pos': 'QB'}
# Added ('Matt Ryan', 'QB') to dictionary
# {'born': datetime.datetime(1985, 5, 17, 0, 0), 'draft': 3, 'pos': 'QB'}
# Added ('Ryan Tannehill', 'QB') to dictionary
# {'born': datetime.datetime(1988, 7, 27, 0, 0), 'draft': 8, 'pos': 'QB'}
# Added ('Carson Palmer', 'QB') to dictionary
# {'born': datetime.datetime(1979, 12, 27, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Robert Griffin III', 'QB') to dictionary
# {'born': datetime.datetime(1990, 2, 12, 0, 0), 'draft': 2, 'pos': 'QB'}
# Added ('Joe Flacco', 'QB') to dictionary
# {'born': datetime.datetime(1985, 1, 16, 0, 0), 'draft': 18, 'pos': 'QB'}
# Added ('Geno Smith', 'QB') to dictionary
# {'born': datetime.datetime(1990, 10, 10, 0, 0), 'draft': 39, 'pos': 'QB'}
# Added ('Eli Manning', 'QB') to dictionary
# {'born': datetime.datetime(1981, 1, 3, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Jay Cutler', 'QB') to dictionary
# {'born': datetime.datetime(1983, 4, 29, 0, 0), 'draft': 11, 'pos': 'QB'}
# Added ('Aaron Rodgers', 'QB') to dictionary
# {'born': datetime.datetime(1983, 12, 2, 0, 0), 'draft': 24, 'pos': 'QB'}
# Added ('Ryan Fitzpatrick', 'QB') to dictionary
# {'born': datetime.datetime(1982, 11, 24, 0, 0), 'draft': 250, 'pos': 'QB'}
# Added ('Chad Henne', 'QB') to dictionary
# {'born': datetime.datetime(1985, 7, 2, 0, 0), 'draft': 57, 'pos': 'QB'}
# Added ('Mike Glennon', 'QB') to dictionary
# {'born': datetime.datetime(1989, 12, 12, 0, 0), 'draft': 73, 'pos': 'QB'}
# Added ('Terrelle Pryor', 'QB') to dictionary
# {'born': datetime.datetime(1989, 6, 20, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Josh McCown', 'QB') to dictionary
# {'born': datetime.datetime(1979, 7, 4, 0, 0), 'draft': 81, 'pos': 'QB'}
# Added ('EJ Manuel', 'QB') to dictionary
# {'born': datetime.datetime(1990, 3, 19, 0, 0), 'draft': 16, 'pos': 'QB'}
# Added ('Rashard Mendenhall', 'RB') to dictionary
# {'born': datetime.datetime(1987, 6, 19, 0, 0), 'draft': 23, 'pos': 'RB'}
# Added ('Donald Brown', 'RB') to dictionary
# {'born': datetime.datetime(1987, 4, 11, 0, 0), 'draft': 27, 'pos': 'RB'}
# Added ('C.J. Spiller', 'RB') to dictionary
# {'born': datetime.datetime(1987, 8, 5, 0, 0), 'draft': 9, 'pos': 'RB'}
# Added ('Jerricho Cotchery', 'WR') to dictionary
# {'born': datetime.datetime(1982, 6, 16, 0, 0), 'draft': 108, 'pos': 'WR'}
# Added ('Ray Rice', 'RB') to dictionary
# {'born': datetime.datetime(1987, 1, 22, 0, 0), 'draft': 55, 'pos': 'RB'}
# Added ('LeGarrette Blount', 'RB') to dictionary
# {'born': datetime.datetime(1986, 12, 5, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Sam Bradford', 'QB') to dictionary
# {'born': datetime.datetime(1987, 11, 8, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Stevan Ridley', 'RB') to dictionary
# {'born': datetime.datetime(1989, 1, 27, 0, 0), 'draft': 73, 'pos': 'RB'}
# Added ('Cordarrelle Patterson', 'WR') to dictionary
# {'born': datetime.datetime(1991, 3, 17, 0, 0), 'draft': 29, 'pos': 'WR'}
# Added ('BenJarvus Green-Ellis', 'RB') to dictionary
# {'born': datetime.datetime(1985, 7, 2, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jason Campbell', 'QB') to dictionary
# {'born': datetime.datetime(1981, 12, 31, 0, 0), 'draft': 25, 'pos': 'QB'}
# Added ('Harry Douglas', 'WR') to dictionary
# {'born': datetime.datetime(1984, 9, 16, 0, 0), 'draft': 84, 'pos': 'WR'}
# Added ('Steven Jackson', 'RB') to dictionary
# {'born': datetime.datetime(1983, 7, 22, 0, 0), 'draft': 24, 'pos': 'RB'}
# Added ('Emmanuel Sanders', 'WR') to dictionary
# {'born': datetime.datetime(1987, 3, 17, 0, 0), 'draft': 82, 'pos': 'WR'}
# Added ('Rod Streater', 'WR') to dictionary
# {'born': datetime.datetime(1988, 2, 9, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Eddie Royal', 'WR') to dictionary
# {'born': datetime.datetime(1986, 5, 21, 0, 0), 'draft': 42, 'pos': 'WR'}
# Added ('Ben Tate', 'RB') to dictionary
# {'born': datetime.datetime(1988, 8, 21, 0, 0), 'draft': 58, 'pos': 'RB'}
# Added ('Trent Richardson', 'RB') to dictionary
# {'born': datetime.datetime(1990, 7, 10, 0, 0), 'draft': 3, 'pos': 'RB'}
# Added ('Nate Washington', 'WR') to dictionary
# {'born': datetime.datetime(1983, 8, 28, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Doug Baldwin', 'WR') to dictionary
# {'born': datetime.datetime(1988, 9, 21, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Matt Cassel', 'QB') to dictionary
# {'born': datetime.datetime(1982, 5, 17, 0, 0), 'draft': 230, 'pos': 'QB'}
# Added ('Christian Ponder', 'QB') to dictionary
# {'born': datetime.datetime(1988, 2, 25, 0, 0), 'draft': 12, 'pos': 'QB'}
# Added ('Matt Schaub', 'QB') to dictionary
# {'born': datetime.datetime(1981, 6, 25, 0, 0), 'draft': 90, 'pos': 'QB'}
# Added ('Greg Jennings', 'WR') to dictionary
# {'born': datetime.datetime(1983, 9, 21, 0, 0), 'draft': 52, 'pos': 'WR'}
# Added ('Case Keenum', 'QB') to dictionary
# {'born': datetime.datetime(1988, 2, 17, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Bilal Powell', 'RB') to dictionary
# {'born': datetime.datetime(1988, 10, 27, 0, 0), 'draft': 126, 'pos': 'RB'}
# Added ('Chris Ivory', 'RB') to dictionary
# {'born': datetime.datetime(1988, 3, 22, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Darren Sproles', 'RB') to dictionary
# {'born': datetime.datetime(1983, 6, 20, 0, 0), 'draft': 130, 'pos': 'RB'}
# Added ('Terrance Williams', 'WR') to dictionary
# {'born': datetime.datetime(1989, 9, 8, 0, 0), 'draft': 74, 'pos': 'WR'}
# Added ('Michael Vick', 'QB') to dictionary
# {'born': datetime.datetime(1980, 6, 26, 0, 0), 'draft': 1, 'pos': 'QB'}
# Added ('Jake Locker', 'QB') to dictionary
# {'born': datetime.datetime(1988, 6, 15, 0, 0), 'draft': 8, 'pos': 'QB'}
# Added ('Denarius Moore', 'WR') to dictionary
# {'born': datetime.datetime(1988, 12, 9, 0, 0), 'draft': 148, 'pos': 'WR'}
# Added ('Steve Smith Sr.', 'WR') to dictionary
# {'born': datetime.datetime(1979, 5, 12, 0, 0), 'draft': 74, 'pos': 'WR'}
# Added ('James Jones', 'WR') to dictionary
# {'born': datetime.datetime(1984, 3, 31, 0, 0), 'draft': 78, 'pos': 'WR'}
# Added ('Lamar Miller', 'RB') to dictionary
# {'born': datetime.datetime(1991, 4, 25, 0, 0), 'draft': 97, 'pos': 'RB'}
# Added ('Dwayne Bowe', 'WR') to dictionary
# {'born': datetime.datetime(1984, 9, 21, 0, 0), 'draft': 23, 'pos': 'WR'}
# Added ('Mike Tolbert', 'RB') to dictionary
# {'born': datetime.datetime(1985, 11, 23, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Marlon Brown', 'WR') to dictionary
# {'born': datetime.datetime(1991, 4, 22, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Cecil Shorts', 'WR') to dictionary
# {'born': datetime.datetime(1987, 12, 22, 0, 0), 'draft': 114, 'pos': 'WR'}
# Added ('Bobby Rainey', 'RB') to dictionary
# {'born': datetime.datetime(1987, 10, 16, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Rueben Randle', 'WR') to dictionary
# {'born': datetime.datetime(1991, 5, 7, 0, 0), 'draft': 63, 'pos': 'WR'}
# Added ('Kenny Stills', 'WR') to dictionary
# {'born': datetime.datetime(1992, 4, 22, 0, 0), 'draft': 144, 'pos': 'WR'}
# Added ('Brandon LaFell', 'WR') to dictionary
# {'born': datetime.datetime(1986, 11, 4, 0, 0), 'draft': 78, 'pos': 'WR'}
# Added ('Jarrett Boykin', 'WR') to dictionary
# {'born': datetime.datetime(1989, 11, 4, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Tavon Austin', 'WR') to dictionary
# {'born': datetime.datetime(1990, 3, 15, 0, 0), 'draft': 8, 'pos': 'WR'}
# Added ('DeAndre Hopkins', 'WR') to dictionary
# {'born': datetime.datetime(1992, 6, 6, 0, 0), 'draft': 27, 'pos': 'WR'}
# Added ('Hakeem Nicks', 'WR') to dictionary
# {'born': datetime.datetime(1988, 1, 14, 0, 0), 'draft': 29, 'pos': 'WR'}
# Added ('Brandon Weeden', 'QB') to dictionary
# {'born': datetime.datetime(1983, 10, 14, 0, 0), 'draft': 22, 'pos': 'QB'}
# Added ('Coby Fleener', 'TE') to dictionary
# {'born': datetime.datetime(1988, 9, 20, 0, 0), 'draft': 34, 'pos': 'TE'}
# Added ('Ted Ginn Jr.', 'WR') to dictionary
# {'born': datetime.datetime(1985, 4, 12, 0, 0), 'draft': 9, 'pos': 'WR'}
# Added ('Jacquizz Rodgers', 'RB') to dictionary
# {'born': datetime.datetime(1990, 2, 6, 0, 0), 'draft': 145, 'pos': 'RB'}
# Added ('Montee Ball', 'RB') to dictionary
# {'born': datetime.datetime(1990, 12, 5, 0, 0), 'draft': 58, 'pos': 'RB'}
# Added ('Shane Vereen', 'RB') to dictionary
# {'born': datetime.datetime(1989, 5, 2, 0, 0), 'draft': 56, 'pos': 'RB'}
# Added ('Arian Foster', 'RB') to dictionary
# {'born': datetime.datetime(1986, 8, 24, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Roddy White', 'WR') to dictionary
# {'born': datetime.datetime(1981, 11, 2, 0, 0), 'draft': 27, 'pos': 'WR'}
# Added ('Tim Wright', 'TE') to dictionary
# {'born': datetime.datetime(1990, 4, 7, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Kellen Clemens', 'QB') to dictionary
# {'born': datetime.datetime(1983, 6, 7, 0, 0), 'draft': 49, 'pos': 'QB'}
# Added ('Brent Celek', 'TE') to dictionary
# {'born': datetime.datetime(1985, 1, 25, 0, 0), 'draft': 162, 'pos': 'TE'}
# Added ('Garrett Graham', 'RB') to dictionary
# {'born': datetime.datetime(1986, 8, 4, 0, 0), 'draft': 118, 'pos': 'TE'}
# Added ('Rob Gronkowski', 'TE') to dictionary
# {'born': datetime.datetime(1989, 5, 14, 0, 0), 'draft': 42, 'pos': 'TE'}
# Added ('Daniel Thomas', 'RB') to dictionary
# {'born': datetime.datetime(1987, 10, 29, 0, 0), 'draft': 62, 'pos': 'RB'}
# Added ('James Starks', 'RB') to dictionary
# {'born': datetime.datetime(1986, 2, 25, 0, 0), 'draft': 193, 'pos': 'RB'}
# Added ('Darren McFadden', 'RB') to dictionary
# {'born': datetime.datetime(1987, 8, 27, 0, 0), 'draft': 4, 'pos': 'RB'}
# Added ('Marcel Reece', 'RB') to dictionary
# {'born': datetime.datetime(1985, 6, 23, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Robert Woods', 'WR') to dictionary
# {'born': datetime.datetime(1992, 4, 10, 0, 0), 'draft': 41, 'pos': 'WR'}
# Added ('Steve Johnson', 'WR') to dictionary
# {'born': datetime.datetime(1986, 11, 28, 0, 0), 'draft': 224, 'pos': 'WR'}
# Added ('Matt McGloin', 'QB') to dictionary
# {'born': datetime.datetime(1989, 12, 2, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Jerome Simpson', 'WR') to dictionary
# {'born': datetime.datetime(1986, 2, 4, 0, 0), 'draft': 46, 'pos': 'WR'}
# Added ('Roy Helu', 'RB') to dictionary
# {'born': datetime.datetime(1988, 12, 7, 0, 0), 'draft': 105, 'pos': 'RB'}
# Added ('Scott Chandler', 'TE') to dictionary
# {'born': datetime.datetime(1985, 7, 23, 0, 0), 'draft': 129, 'pos': 'TE'}
# Added ('Aaron Dobson', 'WR') to dictionary
# {'born': datetime.datetime(1991, 7, 23, 0, 0), 'draft': 59, 'pos': 'WR'}
# Added ('Dexter McCluster', 'WR') to dictionary
# {'born': datetime.datetime(1989, 8, 25, 0, 0), 'draft': 36, 'pos': 'WR'}
# Added ('Brandon Myers', 'TE') to dictionary
# {'born': datetime.datetime(1985, 9, 4, 0, 0), 'draft': 202, 'pos': 'TE'}
# Added ('Danny Amendola', 'WR') to dictionary
# {'born': datetime.datetime(1985, 11, 2, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Randall Cobb', 'WR') to dictionary
# {'born': datetime.datetime(1990, 8, 22, 0, 0), 'draft': 64, 'pos': 'WR'}
# Added ('Andre Brown', 'RB') to dictionary
# {'born': datetime.datetime(1986, 12, 15, 0, 0), 'draft': 129, 'pos': 'RB'}
# Added ('Matt Flynn', 'QB') to dictionary
# {'born': datetime.datetime(1985, 6, 20, 0, 0), 'draft': 209, 'pos': 'QB'}
# Added ('Zach Ertz', 'TE') to dictionary
# {'born': datetime.datetime(1990, 11, 10, 0, 0), 'draft': 35, 'pos': 'TE'}
# Added ('Jeremy Kerley', 'WR') to dictionary
# {'born': datetime.datetime(1988, 11, 8, 0, 0), 'draft': 153, 'pos': 'WR'}
# Added ('Kenbrell Thompkins', 'WR') to dictionary
# {'born': datetime.datetime(1988, 7, 29, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Donnie Avery', 'WR') to dictionary
# {'born': datetime.datetime(1984, 6, 12, 0, 0), 'draft': 33, 'pos': 'WR'}
# Added ('Jordan Reed', 'TE') to dictionary
# {'born': datetime.datetime(1990, 7, 3, 0, 0), 'draft': 85, 'pos': 'TE'}
# Added ('Julio Jones', 'WR') to dictionary
# {'born': datetime.datetime(1989, 2, 8, 0, 0), 'draft': 6, 'pos': 'WR'}
# Added ('Zach Miller', 'TE') to dictionary
# {'born': datetime.datetime(1985, 12, 11, 0, 0), 'draft': 38, 'pos': 'TE'}
# Added ('Tiquan Underwood', 'WR') to dictionary
# {'born': datetime.datetime(1987, 2, 17, 0, 0), 'draft': 253, 'pos': 'WR'}
# Added ('Chris Ogbonnaya', 'RB') to dictionary
# {'born': datetime.datetime(1986, 5, 20, 0, 0), 'draft': 211, 'pos': 'RB'}
# Added ('Bernard Pierce', 'RB') to dictionary
# {'born': datetime.datetime(1991, 5, 10, 0, 0), 'draft': 84, 'pos': 'RB'}
# Added ('Joseph Fauria', 'TE') to dictionary
# {'born': datetime.datetime(1990, 1, 16, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Mychal Rivera', 'TE') to dictionary
# {'born': datetime.datetime(1990, 9, 8, 0, 0), 'draft': 184, 'pos': 'TE'}
# Added ('Reggie Wayne', 'WR') to dictionary
# {'born': datetime.datetime(1978, 11, 17, 0, 0), 'draft': 30, 'pos': 'WR'}
# Added ('Jeff Cumberland', 'TE') to dictionary
# {'born': datetime.datetime(1987, 5, 2, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Jermaine Gresham', 'TE') to dictionary
# {'born': datetime.datetime(1988, 6, 16, 0, 0), 'draft': 21, 'pos': 'TE'}
# Added ('Jacoby Jones', 'WR') to dictionary
# {'born': datetime.datetime(1984, 7, 11, 0, 0), 'draft': 73, 'pos': 'WR'}
# Added ('Austin Pettis', 'WR') to dictionary
# {'born': datetime.datetime(1988, 5, 7, 0, 0), 'draft': 78, 'pos': 'WR'}
# Added ('Heath Miller', 'TE') to dictionary
# {'born': datetime.datetime(1982, 10, 22, 0, 0), 'draft': 30, 'pos': 'TE'}
# Added ('Jason Snelling', 'RB') to dictionary
# {'born': datetime.datetime(1983, 12, 29, 0, 0), 'draft': 244, 'pos': 'RB'}
# Added ('Jarius Wright', 'WR') to dictionary
# {'born': datetime.datetime(1989, 11, 25, 0, 0), 'draft': 118, 'pos': 'WR'}
# Added ('Brandon Bolden', 'RB') to dictionary
# {'born': datetime.datetime(1990, 1, 26, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Knile Davis', 'RB') to dictionary
# {'born': datetime.datetime(1991, 10, 5, 0, 0), 'draft': 96, 'pos': 'RB'}
# Added ('Ace Sanders', 'WR') to dictionary
# {'born': datetime.datetime(1991, 11, 11, 0, 0), 'draft': 101, 'pos': 'WR'}
# Added ('Kris Durham', 'WR') to dictionary
# {'born': datetime.datetime(1988, 3, 17, 0, 0), 'draft': 107, 'pos': 'WR'}
# Added ('Justin Hunter', 'WR') to dictionary
# {'born': datetime.datetime(1991, 5, 20, 0, 0), 'draft': 34, 'pos': 'WR'}
# Added ('Kendall Hunter', 'RB') to dictionary
# {'born': datetime.datetime(1988, 9, 16, 0, 0), 'draft': 115, 'pos': 'RB'}
# Added ('Thaddeus Lewis', 'QB') to dictionary
# {'born': datetime.datetime(1985, 2, 1, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Greg Little', 'WR') to dictionary
# {'born': datetime.datetime(1989, 5, 30, 0, 0), 'draft': 59, 'pos': 'WR'}
# Added ('Andre Roberts', 'WR') to dictionary
# {'born': datetime.datetime(1988, 1, 9, 0, 0), 'draft': 88, 'pos': 'WR'}
# Added ('Marcedes Lewis', 'TE') to dictionary
# {'born': datetime.datetime(1984, 5, 19, 0, 0), 'draft': 28, 'pos': 'TE'}
# Added ('Mohamed Sanu', 'WR') to dictionary
# {'born': datetime.datetime(1989, 8, 23, 0, 0), 'draft': 83, 'pos': 'WR'}
# Added ('Tyler Eifert', 'TE') to dictionary
# {'born': datetime.datetime(1990, 9, 8, 0, 0), 'draft': 21, 'pos': 'TE'}
# Added ('Shonn Greene', 'RB') to dictionary
# {'born': datetime.datetime(1985, 8, 21, 0, 0), 'draft': 65, 'pos': 'RB'}
# Added ('Jermaine Kearse', 'WR') to dictionary
# {'born': datetime.datetime(1990, 2, 6, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Rishard Matthews', 'TE') to dictionary
# {'born': datetime.datetime(1989, 10, 12, 0, 0), 'draft': 227, 'pos': 'WR'}
# Added ('Chris Givens', 'WR') to dictionary
# {'born': datetime.datetime(1989, 12, 6, 0, 0), 'draft': 96, 'pos': 'WR'}
# Added ('Ladarius Green', 'WR') to dictionary
# {'born': datetime.datetime(1990, 5, 29, 0, 0), 'draft': 110, 'pos': 'TE'}
# Added ('Leonard Hankerson', 'WR') to dictionary
# {'born': datetime.datetime(1989, 1, 30, 0, 0), 'draft': 79, 'pos': 'WR'}
# Added ('Doug Martin', 'RB') to dictionary
# {'born': datetime.datetime(1989, 1, 13, 0, 0), 'draft': 31, 'pos': 'RB'}
# Added ('Lance Moore', 'WR') to dictionary
# {'born': datetime.datetime(1983, 8, 31, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Santana Moss', 'WR') to dictionary
# {'born': datetime.datetime(1979, 6, 1, 0, 0), 'draft': 16, 'pos': 'WR'}
# Added ('Jason Avant', 'WR') to dictionary
# {'born': datetime.datetime(1983, 4, 20, 0, 0), 'draft': 109, 'pos': 'WR'}
# Added ('Mike Brown', 'WR') to dictionary
# {'born': datetime.datetime(1989, 2, 9, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jerrel Jernigan', 'WR') to dictionary
# {'born': datetime.datetime(1989, 6, 14, 0, 0), 'draft': 83, 'pos': 'WR'}
# Added ('Jordan Todman', 'RB') to dictionary
# {'born': datetime.datetime(1990, 2, 24, 0, 0), 'draft': 183, 'pos': 'RB'}
# Added ('Bryce Brown', 'RB') to dictionary
# {'born': datetime.datetime(1991, 5, 14, 0, 0), 'draft': 229, 'pos': 'RB'}
# Added ('David Nelson', 'WR') to dictionary
# {'born': datetime.datetime(1986, 11, 7, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Vincent Brown', 'WR') to dictionary
# {'born': datetime.datetime(1989, 1, 25, 0, 0), 'draft': 82, 'pos': None}
# Added ('Dallas Clark', 'TE') to dictionary
# {'born': datetime.datetime(1979, 6, 12, 0, 0), 'draft': 24, 'pos': 'TE'}
# Added ('Santonio Holmes', 'WR') to dictionary
# {'born': datetime.datetime(1984, 3, 3, 0, 0), 'draft': 25, 'pos': 'WR'}
# Added ('Brandon Pettigrew', 'TE') to dictionary
# {'born': datetime.datetime(1985, 2, 23, 0, 0), 'draft': 20, 'pos': 'TE'}
# Added ('Nate Burleson', 'WR') to dictionary
# {'born': datetime.datetime(1981, 8, 19, 0, 0), 'draft': 71, 'pos': 'WR'}
# Added ('Brandon Gibson', 'WR') to dictionary
# {'born': datetime.datetime(1987, 8, 13, 0, 0), 'draft': 194, 'pos': 'WR'}
# Added ('Rob Housler', 'TE') to dictionary
# {'born': datetime.datetime(1988, 3, 17, 0, 0), 'draft': 69, 'pos': 'TE'}
# Added ('Mark Ingram', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 21, 0, 0), 'draft': 28, 'pos': 'RB'}
# Added ('Kellen Winslow', 'TE') to dictionary
# {'born': datetime.datetime(1983, 7, 21, 0, 0), 'draft': 6, 'pos': 'TE'}
# Added ('Earl Bennett', 'WR') to dictionary
# {'born': datetime.datetime(1987, 3, 23, 0, 0), 'draft': 70, 'pos': 'WR'}
# Added ('Lance Kendricks', 'TE') to dictionary
# {'born': datetime.datetime(1988, 1, 30, 0, 0), 'draft': 47, 'pos': 'TE'}
# Added ('Willis McGahee', 'RB') to dictionary
# {'born': datetime.datetime(1981, 10, 21, 0, 0), 'draft': 23, 'pos': 'RB'}
# Added ('Cole Beasley', 'WR') to dictionary
# {'born': datetime.datetime(1989, 4, 26, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Michael Bush', 'RB') to dictionary
# {'born': datetime.datetime(1984, 6, 16, 0, 0), 'draft': 100, 'pos': 'RB'}
# Added ('Andre Holmes', 'WR') to dictionary
# {'born': datetime.datetime(1988, 6, 16, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Kyle Rudolph', 'TE') to dictionary
# {'born': datetime.datetime(1989, 11, 9, 0, 0), 'draft': 43, 'pos': 'TE'}
# Added ('Davone Bess', 'WR') to dictionary
# {'born': datetime.datetime(1985, 9, 13, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jermichael Finley', 'TE') to dictionary
# {'born': datetime.datetime(1987, 3, 26, 0, 0), 'draft': 91, 'pos': 'TE'}
# Added ('T.J. Graham', 'WR') to dictionary
# {'born': datetime.datetime(1989, 7, 4, 0, 0), 'draft': 69, 'pos': 'WR'}
# Added ('Aldrick Robinson', 'WR') to dictionary
# {'born': datetime.datetime(1988, 9, 24, 0, 0), 'draft': 178, 'pos': 'WR'}
# Added ('Justin Blackmon', 'WR') to dictionary
# {'born': datetime.datetime(1990, 1, 9, 0, 0), 'draft': 5, 'pos': 'WR'}
# Added ('Toby Gerhart', 'RB') to dictionary
# {'born': datetime.datetime(1987, 3, 28, 0, 0), 'draft': 51, 'pos': 'RB'}
# Added ('Brandon Jacobs', 'RB') to dictionary
# {'born': datetime.datetime(1982, 7, 6, 0, 0), 'draft': 110, 'pos': 'RB'}
# Added ('Marquise Goodwin', 'WR') to dictionary
# {'born': datetime.datetime(1990, 11, 19, 0, 0), 'draft': 78, 'pos': 'WR'}
# Added ('Peyton Hillis', 'RB') to dictionary
# {'born': datetime.datetime(1986, 1, 21, 0, 0), 'draft': 227, 'pos': 'RB'}
# Added ('Robert Meachem', 'WR') to dictionary
# {'born': datetime.datetime(1984, 9, 28, 0, 0), 'draft': 27, 'pos': 'WR'}
# Added ('Owen Daniels', 'TE') to dictionary
# {'born': datetime.datetime(1982, 11, 9, 0, 0), 'draft': 98, 'pos': 'TE'}
# Added ('Andrew Quarless', 'TE') to dictionary
# {'born': datetime.datetime(1988, 10, 6, 0, 0), 'draft': 154, 'pos': 'TE'}
# Added ('Darrius Heyward-Bey', 'WR') to dictionary
# {'born': datetime.datetime(1987, 2, 26, 0, 0), 'draft': 7, 'pos': 'WR'}
# Added ('Sean McGrath', 'TE') to dictionary
# {'born': datetime.datetime(1987, 12, 3, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Brian Quick', 'WR') to dictionary
# {'born': datetime.datetime(1989, 6, 5, 0, 0), 'draft': 33, 'pos': 'WR'}
# Added ('Keshawn Martin', 'WR') to dictionary
# {'born': datetime.datetime(1990, 3, 15, 0, 0), 'draft': 121, 'pos': 'WR'}
# Added ('Logan Paulsen', 'TE') to dictionary
# {'born': datetime.datetime(1987, 2, 26, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Brian Hoyer', 'QB') to dictionary
# {'born': datetime.datetime(1985, 10, 13, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Andre Caldwell', 'WR') to dictionary
# {'born': datetime.datetime(1985, 4, 15, 0, 0), 'draft': 97, 'pos': 'WR'}
# Added ('Clay Harbor', 'TE') to dictionary
# {'born': datetime.datetime(1987, 7, 2, 0, 0), 'draft': 125, 'pos': 'TE'}
# Added ('Kevin Ogletree', 'WR') to dictionary
# {'born': datetime.datetime(1987, 8, 5, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Sidney Rice', 'WR') to dictionary
# {'born': datetime.datetime(1986, 9, 1, 0, 0), 'draft': 44, 'pos': 'WR'}
# Added ('John Carlson', 'TE') to dictionary
# {'born': datetime.datetime(1984, 5, 12, 0, 0), 'draft': 38, 'pos': 'TE'}
# Added ('Benny Cunningham', 'RB') to dictionary
# {'born': datetime.datetime(1990, 7, 7, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Anthony Fasano', 'TE') to dictionary
# {'born': datetime.datetime(1984, 4, 20, 0, 0), 'draft': 53, 'pos': 'TE'}
# Added ('Ronnie Hillman', 'RB') to dictionary
# {'born': datetime.datetime(1991, 9, 14, 0, 0), 'draft': 67, 'pos': 'RB'}
# Added ('Stephen Hill', 'WR') to dictionary
# {'born': datetime.datetime(1991, 4, 25, 0, 0), 'draft': 43, 'pos': 'WR'}
# Added ('Mike James', 'RB') to dictionary
# {'born': datetime.datetime(1991, 4, 13, 0, 0), 'draft': 189, 'pos': 'RB'}
# Added ('Griff Whalen', 'WR') to dictionary
# {'born': datetime.datetime(1990, 3, 1, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Brian Leonard', 'RB') to dictionary
# {'born': datetime.datetime(1984, 2, 3, 0, 0), 'draft': 52, 'pos': 'RB'}
# Added ('Edwin Baker', 'RB') to dictionary
# {'born': datetime.datetime(1991, 6, 1, 0, 0), 'draft': 250, 'pos': 'RB'}
# Added ('Ahmad Bradshaw', 'RB') to dictionary
# {'born': datetime.datetime(1986, 3, 19, 0, 0), 'draft': 250, 'pos': 'RB'}
# Added ('Tandon Doss', 'WR') to dictionary
# {'born': datetime.datetime(1989, 9, 22, 0, 0), 'draft': 123, 'pos': 'WR'}
# Added ('Joseph Randle', 'RB') to dictionary
# {'born': datetime.datetime(1991, 12, 29, 0, 0), 'draft': 151, 'pos': 'RB'}
# Added ('Ben Watson', 'TE') to dictionary
# {'born': datetime.datetime(1980, 12, 18, 0, 0), 'draft': 32, 'pos': 'TE'}
# Added ('Fozzy Whittaker', 'RB') to dictionary
# {'born': datetime.datetime(1989, 2, 2, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Darrel Young', 'RB') to dictionary
# {'born': datetime.datetime(1987, 4, 8, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Matt Asiata', 'RB') to dictionary
# {'born': datetime.datetime(1987, 7, 24, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Kirk Cousins', 'QB') to dictionary
# {'born': datetime.datetime(1988, 8, 19, 0, 0), 'draft': 102, 'pos': 'QB'}
# Added ('Michael Crabtree', 'WR') to dictionary
# {'born': datetime.datetime(1987, 9, 14, 0, 0), 'draft': 10, 'pos': 'WR'}
# Added ('Drew Davis', 'WR') to dictionary
# {'born': datetime.datetime(1989, 1, 4, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Chris Polk', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 16, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Daryl Richardson', 'RB') to dictionary
# {'born': datetime.datetime(1990, 4, 12, 0, 0), 'draft': 252, 'pos': 'RB'}
# Added ('Scott Tolzien', 'QB') to dictionary
# {'born': datetime.datetime(1987, 9, 4, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Mike Williams', 'WR') to dictionary
# {'born': datetime.datetime(1987, 5, 18, 0, 0), 'draft': 101, 'pos': 'WR'}
# Added ('Ed Dickson', 'TE') to dictionary
# {'born': datetime.datetime(1987, 7, 25, 0, 0), 'draft': 70, 'pos': 'TE'}
# Added ('Luke Willson', 'TE') to dictionary
# {'born': datetime.datetime(1990, 1, 15, 0, 0), 'draft': 158, 'pos': 'TE'}
# Added ('Stedman Bailey', 'WR') to dictionary
# {'born': datetime.datetime(1990, 11, 11, 0, 0), 'draft': 92, 'pos': 'WR'}
# Added ('Jim Dray', 'TE') to dictionary
# {'born': datetime.datetime(1986, 12, 31, 0, 0), 'draft': 233, 'pos': 'TE'}
# Added ("Da'Rick Rogers", 'WR') to dictionary
# {'born': datetime.datetime(1991, 6, 18, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Josh Freeman', 'QB') to dictionary
# {'born': datetime.datetime(1988, 1, 13, 0, 0), 'draft': 17, 'pos': 'QB'}
# Added ('Ryan Griffin', 'TE') to dictionary
# {'born': datetime.datetime(1990, 1, 11, 0, 0), 'draft': 201, 'pos': 'TE'}
# Added ('Robert Turbin', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 2, 0, 0), 'draft': 106, 'pos': 'RB'}
# Added ('Kerry Taylor', 'WR') to dictionary
# {'born': datetime.datetime(1989, 2, 20, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('LaVon Brazill', 'WR') to dictionary
# {'born': datetime.datetime(1989, 3, 15, 0, 0), 'draft': 206, 'pos': 'WR'}
# Added ('Ronnie Brown', 'RB') to dictionary
# {'born': datetime.datetime(1981, 12, 12, 0, 0), 'draft': 2, 'pos': 'RB'}
# Added ('Khiry Robinson', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 28, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Antone Smith', 'RB') to dictionary
# {'born': datetime.datetime(1985, 9, 17, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jeremy Ross', 'WR') to dictionary
# {'born': datetime.datetime(1988, 3, 16, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jonathan Dwyer', 'RB') to dictionary
# {'born': datetime.datetime(1989, 7, 26, 0, 0), 'draft': 188, 'pos': 'RB'}
# Added ('Bruce Miller', 'RB') to dictionary
# {'born': datetime.datetime(1987, 8, 6, 0, 0), 'draft': 211, 'pos': 'FB'}
# Added ('Gary Barnidge', 'TE') to dictionary
# {'born': datetime.datetime(1985, 9, 22, 0, 0), 'draft': 141, 'pos': 'TE'}
# Added ('Gavin Escobar', 'TE') to dictionary
# {'born': datetime.datetime(1991, 2, 3, 0, 0), 'draft': 47, 'pos': 'TE'}
# Added ('Dwayne Harris', 'WR') to dictionary
# {'born': datetime.datetime(1987, 9, 16, 0, 0), 'draft': 176, 'pos': 'WR'}
# Added ('Darius Johnson', 'WR') to dictionary
# {'born': datetime.datetime(1991, 2, 22, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Frank Summers', 'RB') to dictionary
# {'born': datetime.datetime(1985, 9, 6, 0, 0), 'draft': 169, 'pos': 'RB'}
# Added ('Miles Austin', 'WR') to dictionary
# {'born': datetime.datetime(1984, 6, 30, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jackie Battle', 'RB') to dictionary
# {'born': datetime.datetime(1983, 10, 1, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ("Da'Rel Scott", 'RB') to dictionary
# {'born': datetime.datetime(1988, 5, 2, 0, 0), 'draft': 221, 'pos': 'RB'}
# Added ('Jacob Tamme', 'TE') to dictionary
# {'born': datetime.datetime(1985, 3, 15, 0, 0), 'draft': 127, 'pos': 'TE'}
# Added ('Cory Harkey', 'RB') to dictionary
# {'born': datetime.datetime(1990, 6, 17, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Junior Hemingway', 'WR') to dictionary
# {'born': datetime.datetime(1988, 12, 27, 0, 0), 'draft': 238, 'pos': 'WR'}
# Added ('Dennis Johnson', 'RB') to dictionary
# {'born': datetime.datetime(1990, 2, 24, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Felix Jones', 'RB') to dictionary
# {'born': datetime.datetime(1987, 5, 8, 0, 0), 'draft': 22, 'pos': 'RB'}
# Added ('Josh Morgan', 'WR') to dictionary
# {'born': datetime.datetime(1985, 6, 20, 0, 0), 'draft': 174, 'pos': 'WR'}
# Added ('Dennis Pitta', 'TE') to dictionary
# {'born': datetime.datetime(1985, 6, 29, 0, 0), 'draft': 114, 'pos': 'TE'}
# Added ('Jonathan Stewart', 'RB') to dictionary
# {'born': datetime.datetime(1987, 3, 21, 0, 0), 'draft': 13, 'pos': 'RB'}
# Added ('Anthony Dixon', 'RB') to dictionary
# {'born': datetime.datetime(1987, 9, 24, 0, 0), 'draft': 173, 'pos': 'RB'}
# Added ('Kyle Orton', 'QB') to dictionary
# {'born': datetime.datetime(1982, 11, 14, 0, 0), 'draft': 106, 'pos': 'QB'}
# Added ('Jake Ballard', 'TE') to dictionary
# {'born': datetime.datetime(1987, 12, 2, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Jaron Brown', 'WR') to dictionary
# {'born': datetime.datetime(1990, 1, 8, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Stanley Havili', 'RB') to dictionary
# {'born': datetime.datetime(1987, 11, 14, 0, 0), 'draft': 240, 'pos': 'RB'}
# Added ('Andrew Hawkins', 'WR') to dictionary
# {'born': datetime.datetime(1986, 3, 10, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Michael Hoomanawanui', 'TE') to dictionary
# {'born': datetime.datetime(1988, 7, 4, 0, 0), 'draft': 132, 'pos': 'TE'}
# Added ('Anthony Sherman', 'RB') to dictionary
# {'born': datetime.datetime(1988, 12, 11, 0, 0), 'draft': 136, 'pos': 'RB'}
# Added ('Travis Benjamin', 'WR') to dictionary
# {'born': datetime.datetime(1989, 12, 29, 0, 0), 'draft': 100, 'pos': 'WR'}
# Added ('Tashard Choice', 'RB') to dictionary
# {'born': datetime.datetime(1984, 11, 20, 0, 0), 'draft': 122, 'pos': 'RB'}
# Added ('Lance Dunbar', 'RB') to dictionary
# {'born': datetime.datetime(1990, 1, 25, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jonathan Grimes', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 21, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Stepfan Taylor', 'RB') to dictionary
# {'born': datetime.datetime(1991, 6, 9, 0, 0), 'draft': 140, 'pos': 'RB'}
# Added ('Brandon Bostick', 'TE') to dictionary
# {'born': datetime.datetime(1989, 5, 3, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Johnathan Franklin', 'RB') to dictionary
# {'born': datetime.datetime(1989, 10, 23, 0, 0), 'draft': 125, 'pos': 'RB'}
# Added ('Marcus Thigpen', 'RB') to dictionary
# {'born': datetime.datetime(1986, 5, 15, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Levine Toilolo', 'TE') to dictionary
# {'born': datetime.datetime(1991, 7, 30, 0, 0), 'draft': 133, 'pos': 'TE'}
# Added ('Chase Daniel', 'QB') to dictionary
# {'born': datetime.datetime(1986, 10, 7, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('David Wilson', 'RB') to dictionary
# {'born': datetime.datetime(1991, 6, 15, 0, 0), 'draft': 32, 'pos': 'RB'}
# Added ('Jed Collins', 'RB') to dictionary
# {'born': datetime.datetime(1986, 3, 3, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Tarvaris Jackson', 'QB') to dictionary
# {'born': datetime.datetime(1983, 4, 21, 0, 0), 'draft': 64, 'pos': 'QB'}
# Added ('John Kuhn', 'RB') to dictionary
# {'born': datetime.datetime(1982, 9, 9, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('DeVier Posey', 'WR') to dictionary
# {'born': datetime.datetime(1990, 3, 15, 0, 0), 'draft': 68, 'pos': 'WR'}
# Added ('Michael Preston', 'WR') to dictionary
# {'born': datetime.datetime(1989, 6, 1, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Alfonso Smith', 'RB') to dictionary
# {'born': datetime.datetime(1987, 1, 23, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Damian Williams', 'WR') to dictionary
# {'born': datetime.datetime(1988, 5, 26, 0, 0), 'draft': 77, 'pos': 'WR'}
# Added ('Malcom Floyd', 'WR') to dictionary
# {'born': datetime.datetime(1981, 9, 8, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Brittan Golden', 'WR') to dictionary
# {'born': datetime.datetime(1988, 7, 20, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('A.J. Jenkins', 'WR') to dictionary
# {'born': datetime.datetime(1989, 9, 30, 0, 0), 'draft': 30, 'pos': 'WR'}
# Added ('Greg Salas', 'WR') to dictionary
# {'born': datetime.datetime(1988, 8, 25, 0, 0), 'draft': 112, 'pos': 'WR'}
# Added ('Kyle Williams', 'WR') to dictionary
# {'born': datetime.datetime(1988, 7, 19, 0, 0), 'draft': 206, 'pos': 'WR'}
# Added ('Tommy Bohanon', 'RB') to dictionary
# {'born': datetime.datetime(1990, 9, 10, 0, 0), 'draft': 215, 'pos': 'FB'}
# Added ('Derrick Coleman', 'RB') to dictionary
# {'born': datetime.datetime(1990, 10, 18, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Fred Davis', 'TE') to dictionary
# {'born': datetime.datetime(1986, 1, 15, 0, 0), 'draft': 48, 'pos': 'TE'}
# Added ('James Develin', 'TE') to dictionary
# {'born': datetime.datetime(1988, 7, 23, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Chase Ford', 'TE') to dictionary
# {'born': datetime.datetime(1990, 7, 19, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Vonta Leach', 'RB') to dictionary
# {'born': datetime.datetime(1981, 11, 6, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jeff Maehl', 'WR') to dictionary
# {'born': datetime.datetime(1989, 3, 16, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Seyi Ajirotutu', 'WR') to dictionary
# {'born': datetime.datetime(1987, 6, 12, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Josh Boyce', 'WR') to dictionary
# {'born': datetime.datetime(1991, 5, 6, 0, 0), 'draft': 102, 'pos': 'WR'}
# Added ('Rhett Ellison', 'RB') to dictionary
# {'born': datetime.datetime(1988, 10, 3, 0, 0), 'draft': 128, 'pos': 'FB'}
# Added ('Blaine Gabbert', 'QB') to dictionary
# {'born': datetime.datetime(1989, 10, 15, 0, 0), 'draft': 10, 'pos': 'QB'}
# Added ('Clyde Gates', 'WR') to dictionary
# {'born': datetime.datetime(1986, 6, 13, 0, 0), 'draft': 111, 'pos': 'WR'}
# Added ('Domenik Hixon', 'WR') to dictionary
# {'born': datetime.datetime(1984, 10, 8, 0, 0), 'draft': 130, 'pos': 'WR'}
# Added ('Vance McDonald ', 'TE') to dictionary
# {'born': datetime.datetime(1990, 6, 13, 0, 0), 'draft': 55, 'pos': 'TE'}
# Added ('Danny Noble', 'TE') to dictionary
# {'born': datetime.datetime(1989, 3, 30, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Isaiah Pead', 'RB') to dictionary
# {'born': datetime.datetime(1989, 12, 14, 0, 0), 'draft': 50, 'pos': 'RB'}
# Added ('Brandon Stokley', 'WR') to dictionary
# {'born': datetime.datetime(1976, 6, 23, 0, 0), 'draft': 105, 'pos': 'WR'}
# Added ('Jeff Tuel', 'QB') to dictionary
# {'born': datetime.datetime(1991, 2, 12, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Joel Dreessen', 'TE') to dictionary
# {'born': datetime.datetime(1982, 7, 26, 0, 0), 'draft': 198, 'pos': 'TE'}
# Added ('Justin Forsett', 'RB') to dictionary
# {'born': datetime.datetime(1985, 10, 14, 0, 0), 'draft': 233, 'pos': 'RB'}
# Added ('Chris Gragg', 'TE') to dictionary
# {'born': datetime.datetime(1990, 6, 30, 0, 0), 'draft': 222, 'pos': 'TE'}
# Added ('Chris Owusu', 'WR') to dictionary
# {'born': datetime.datetime(1990, 1, 6, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Theo Riddick', 'RB') to dictionary
# {'born': datetime.datetime(1991, 5, 4, 0, 0), 'draft': 199, 'pos': 'RB'}
# Added ('Phillip Tanner', 'RB') to dictionary
# {'born': datetime.datetime(1988, 8, 8, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Kenny Britt', 'WR') to dictionary
# {'born': datetime.datetime(1988, 9, 19, 0, 0), 'draft': 30, 'pos': 'WR'}
# Added ('Brice Butler', 'WR') to dictionary
# {'born': datetime.datetime(1990, 1, 29, 0, 0), 'draft': 209, 'pos': 'WR'}
# Added ('Josh Hill', 'TE') to dictionary
# {'born': datetime.datetime(1990, 5, 21, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Will Johnson', 'RB') to dictionary
# {'born': datetime.datetime(1989, 11, 14, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Matt Simms', 'QB') to dictionary
# {'born': datetime.datetime(1988, 9, 27, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Deonte Thompson', 'WR') to dictionary
# {'born': datetime.datetime(1989, 2, 14, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Ryan Broyles', 'WR') to dictionary
# {'born': datetime.datetime(1988, 4, 9, 0, 0), 'draft': 54, 'pos': 'WR'}
# Added ('Kellen Davis', 'TE') to dictionary
# {'born': datetime.datetime(1985, 10, 11, 0, 0), 'draft': 158, 'pos': 'TE'}
# Added ('Jacoby Ford', 'WR') to dictionary
# {'born': datetime.datetime(1987, 7, 27, 0, 0), 'draft': 108, 'pos': 'WR'}
# Added ('Dan Herron', 'RB') to dictionary
# {'born': datetime.datetime(1989, 3, 21, 0, 0), 'draft': 191, 'pos': 'RB'}
# Added ('Trindon Holliday', 'WR') to dictionary
# {'born': datetime.datetime(1986, 4, 27, 0, 0), 'draft': 197, 'pos': 'WR'}
# Added ('Mario Manningham', 'WR') to dictionary
# {'born': datetime.datetime(1986, 5, 25, 0, 0), 'draft': 95, 'pos': 'WR'}
# Added ('Jeron Mastrud', 'TE') to dictionary
# {'born': datetime.datetime(1987, 12, 17, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Dion Sims', 'TE') to dictionary
# {'born': datetime.datetime(1991, 2, 18, 0, 0), 'draft': 106, 'pos': 'TE'}
# Added ('Dwayne Allen', 'TE') to dictionary
# {'born': datetime.datetime(1990, 2, 24, 0, 0), 'draft': 64, 'pos': 'TE'}
# Added ('Tom Crabtree', 'TE') to dictionary
# {'born': datetime.datetime(1985, 11, 4, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Josh Cribbs', 'WR') to dictionary
# {'born': datetime.datetime(1983, 6, 9, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Mike Goodson', 'RB') to dictionary
# {'born': datetime.datetime(1987, 5, 23, 0, 0), 'draft': 111, 'pos': 'RB'}
# Added ('Chris Hogan', 'WR') to dictionary
# {'born': datetime.datetime(1987, 10, 24, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('LaMichael James', 'RB') to dictionary
# {'born': datetime.datetime(1989, 10, 22, 0, 0), 'draft': 61, 'pos': 'RB'}
# Added ('Ricardo Lockette', 'WR') to dictionary
# {'born': datetime.datetime(1986, 5, 21, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Christine Michael', 'RB') to dictionary
# {'born': datetime.datetime(1990, 11, 9, 0, 0), 'draft': 62, 'pos': 'RB'}
# Added ('Derek Moye', 'WR') to dictionary
# {'born': datetime.datetime(1988, 8, 12, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Matthew Mulligan', 'TE') to dictionary
# {'born': datetime.datetime(1985, 1, 18, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Louis Murphy', 'WR') to dictionary
# {'born': datetime.datetime(1987, 5, 11, 0, 0), 'draft': 124, 'pos': 'WR'}
# Added ('Kassim Osgood', 'WR') to dictionary
# {'born': datetime.datetime(1980, 5, 20, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Bear Pascoe', 'TE') to dictionary
# {'born': datetime.datetime(1986, 2, 23, 0, 0), 'draft': 184, 'pos': 'TE'}
# Added ('David Paulson', 'TE') to dictionary
# {'born': datetime.datetime(1989, 2, 22, 0, 0), 'draft': 240, 'pos': 'TE'}
# Added ('Tony Scheffler', 'TE') to dictionary
# {'born': datetime.datetime(1983, 2, 15, 0, 0), 'draft': 61, 'pos': 'TE'}
# Added ('Lee Smith', 'WR') to dictionary
# {'born': datetime.datetime(1987, 11, 21, 0, 0), 'draft': 159, 'pos': 'TE'}
# Added ('Stephen Burton', 'WR') to dictionary
# {'born': datetime.datetime(1989, 12, 11, 0, 0), 'draft': 236, 'pos': 'WR'}
# Added ('Travaris Cadet', 'RB') to dictionary
# {'born': datetime.datetime(1989, 2, 1, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Michael Egnew', 'TE') to dictionary
# {'born': datetime.datetime(1989, 11, 1, 0, 0), 'draft': 78, 'pos': 'TE'}
# Added ('Cyrus Gray', 'RB') to dictionary
# {'born': datetime.datetime(1989, 11, 18, 0, 0), 'draft': 182, 'pos': 'RB'}
# Added ('James Hanna', 'TE') to dictionary
# {'born': datetime.datetime(1989, 7, 14, 0, 0), 'draft': 186, 'pos': 'TE'}
# Added ('David Johnson', 'TE') to dictionary
# {'born': datetime.datetime(1987, 8, 26, 0, 0), 'draft': 241, 'pos': 'TE'}
# Added ('Nick Kasa', 'TE') to dictionary
# {'born': datetime.datetime(1990, 11, 5, 0, 0), 'draft': 172, 'pos': 'TE'}
# Added ('Marlon Moore', 'WR') to dictionary
# {'born': datetime.datetime(1987, 9, 3, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jamize Olawale', 'RB') to dictionary
# {'born': datetime.datetime(1989, 4, 17, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Alex Smith', 'TE') to dictionary
# {'born': datetime.datetime(1982, 5, 22, 0, 0), 'draft': 71, 'pos': 'TE'}
# ...
# Added ('Nico Collins', 'WR') to dictionary
# {'born': datetime.datetime(1999, 3, 19, 0, 0), 'draft': 89, 'pos': 'WR'}
# Added ('Derrick Gore', 'RB') to dictionary
# {'born': datetime.datetime(1994, 12, 13, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Jaret Patterson', 'RB') to dictionary
# {'born': datetime.datetime(1999, 12, 23, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Mike White', 'QB') to dictionary
# {'born': datetime.datetime(1995, 3, 25, 0, 0), 'draft': 171, 'pos': 'QB'}
# Added ('Kadarius Toney', 'WR') to dictionary
# {'born': datetime.datetime(1999, 1, 27, 0, 0), 'draft': 20, 'pos': 'WR'}
# Added ('Antoine Wesley', 'WR') to dictionary
# {'born': datetime.datetime(1997, 10, 22, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Brevin Jordan', 'TE') to dictionary
# {'born': datetime.datetime(2000, 7, 16, 0, 0), 'draft': 147, 'pos': 'TE'}
# Added ('Chris Evans', 'RB') to dictionary
# {'born': datetime.datetime(1997, 10, 5, 0, 0), 'draft': 202, 'pos': 'RB'}
# Added ('Demetric Felton', 'RB') to dictionary
# {'born': datetime.datetime(1998, 7, 16, 0, 0), 'draft': 211, 'pos': 'RB'}
# Added ('Tommy Tremble', 'TE') to dictionary
# {'born': datetime.datetime(2000, 6, 2, 0, 0), 'draft': 83, 'pos': 'TE'}
# Added ("Ty'Son Williams", 'RB') to dictionary
# {'born': datetime.datetime(1996, 9, 4, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('John Bates', 'TE') to dictionary
# {'born': datetime.datetime(1997, 11, 6, 0, 0), 'draft': 124, 'pos': 'TE'}
# Added ('Trey Sermon', 'RB') to dictionary
# {'born': datetime.datetime(1999, 1, 30, 0, 0), 'draft': 88, 'pos': 'RB'}
# Added ('Ihmir Smith-Marsette', 'WR') to dictionary
# {'born': datetime.datetime(1999, 8, 29, 0, 0), 'draft': 157, 'pos': 'WR'}
# Added ('Brock Wright', 'TE') to dictionary
# {'born': datetime.datetime(1998, 11, 27, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Anthony Schwartz', 'WR') to dictionary
# {'born': datetime.datetime(2000, 9, 5, 0, 0), 'draft': 91, 'pos': 'WR'}
# Added ('Eno Benjamin', 'RB') to dictionary
# {'born': datetime.datetime(1999, 4, 13, 0, 0), 'draft': 222, 'pos': 'RB'}
# Added ('Jermar Jefferson', 'RB') to dictionary
# {'born': datetime.datetime(2000, 4, 15, 0, 0), 'draft': 257, 'pos': 'RB'}
# Added ('Jordan Love', 'QB') to dictionary
# {'born': datetime.datetime(1998, 11, 2, 0, 0), 'draft': 26, 'pos': 'QB'}
# Added ('Godwin Igwebuike', 'RB') to dictionary
# {'born': datetime.datetime(1994, 9, 10, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Kene Nwangwu', 'RB') to dictionary
# {'born': datetime.datetime(1998, 2, 9, 0, 0), 'draft': 119, 'pos': 'RB'}
# Added ("D'Wayne Eskridge", 'WR') to dictionary
# {'born': datetime.datetime(1997, 3, 23, 0, 0), 'draft': 56, 'pos': 'WR'}
# Added ('Joe Fortson', 'TE') to dictionary
# {'born': datetime.datetime(1995, 12, 7, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Dyami Brown', 'WR') to dictionary
# {'born': datetime.datetime(1999, 11, 1, 0, 0), 'draft': 82, 'pos': 'WR'}
# Added ('Terrace Marshall Jr.', 'WR') to dictionary
# {'born': datetime.datetime(2000, 6, 9, 0, 0), 'draft': 59, 'pos': 'WR'}
# Added ('Kristian Wilkerson', 'WR') to dictionary
# {'born': datetime.datetime(1997, 1, 10, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Larry Rountree', 'RB') to dictionary
# {'born': datetime.datetime(1999, 2, 13, 0, 0), 'draft': 198, 'pos': 'RB'}
# Added ('Patrick Taylor', 'RB') to dictionary
# {'born': datetime.datetime(1998, 4, 29, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Ben Skowronek', 'WR') to dictionary
# {'born': datetime.datetime(1997, 6, 27, 0, 0), 'draft': 249, 'pos': 'WR'}
# Added ('Tom Kennedy', 'WR') to dictionary
# {'born': datetime.datetime(1996, 7, 29, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Dez Fitzpatrick', 'WR') to dictionary
# {'born': datetime.datetime(1997, 12, 17, 0, 0), 'draft': 109, 'pos': 'WR'}
# Added ('Jake Fromm', 'QB') to dictionary
# {'born': datetime.datetime(1998, 7, 30, 0, 0), 'draft': 167, 'pos': 'QB'}
# Added ('Kylen Granson', 'TE') to dictionary
# {'born': datetime.datetime(1998, 3, 27, 0, 0), 'draft': 127, 'pos': 'TE'}
# Added ('Trinity Benson', 'WR') to dictionary
# {'born': datetime.datetime(1997, 1, 16, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jason Cabinda', 'RB') to dictionary
# {'born': datetime.datetime(1996, 3, 17, 0, 0), 'draft': None, 'pos': 'IL'}
# Added ('Noah Gray', 'TE') to dictionary
# {'born': datetime.datetime(1999, 4, 30, 0, 0), 'draft': 162, 'pos': 'TE'}
# Added ('Shi Smith', 'WR') to dictionary
# {'born': datetime.datetime(1998, 10, 26, 0, 0), 'draft': 204, 'pos': 'WR'}
# Added ('JaQuan Hardy', 'RB') to dictionary
# {'born': datetime.datetime(1997, 12, 31, 0, 0), 'draft': None, 'pos': None}
# Added ('Deon Jackson', 'RB') to dictionary
# {'born': datetime.datetime(1999, 2, 18, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Sean McKeon', 'TE') to dictionary
# {'born': datetime.datetime(1997, 12, 28, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Tyree Jackson', 'TE') to dictionary
# {'born': datetime.datetime(1997, 11, 7, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Chris Myarick', 'TE') to dictionary
# {'born': datetime.datetime(1995, 10, 6, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Dezmon Patmon', 'WR') to dictionary
# {'born': datetime.datetime(1998, 8, 6, 0, 0), 'draft': 212, 'pos': 'WR'}
# Added ('Johnny Stanton', 'RB') to dictionary
# {'born': datetime.datetime(1994, 9, 7, 0, 0), 'draft': None, 'pos': 'FB'}
# Added ('Luke Farrell', 'TE') to dictionary
# {'born': datetime.datetime(1997, 10, 14, 0, 0), 'draft': 145, 'pos': 'TE'}
# Added ('Dax Milne', 'WR') to dictionary
# {'born': datetime.datetime(1999, 6, 23, 0, 0), 'draft': 258, 'pos': 'WR'}
# Added ('Brandon Powell', '') to dictionary
# {'born': datetime.datetime(1995, 9, 12, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Amari Rodgers', 'WR') to dictionary
# {'born': datetime.datetime(1999, 9, 23, 0, 0), 'draft': 85, 'pos': 'WR'}
# Added ('Jaelon Darden', 'WR') to dictionary
# {'born': datetime.datetime(1999, 1, 14, 0, 0), 'draft': 129, 'pos': 'WR'}
# Added ("Tre' McKitty", 'TE') to dictionary
# {'born': datetime.datetime(1999, 1, 12, 0, 0), 'draft': 97, 'pos': 'TE'}
# Added ('Kendall Blanton', 'TE') to dictionary
# {'born': datetime.datetime(1995, 11, 10, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Tyler Davis', 'TE') to dictionary
# {'born': datetime.datetime(1997, 4, 2, 0, 0), 'draft': 206, 'pos': 'TE'}
# Added ('Greg Dortch', 'WR') to dictionary
# {'born': datetime.datetime(1998, 5, 29, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Parker Hesse', 'TE') to dictionary
# {'born': datetime.datetime(1995, 5, 26, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('D.J. Montgomery', 'WR') to dictionary
# {'born': datetime.datetime(1996, 11, 17, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Juwann Winfree', 'WR') to dictionary
# {'born': datetime.datetime(1996, 9, 4, 0, 0), 'draft': 187, 'pos': 'WR'}
# Added ('Kenny Yeboah', 'TE') to dictionary
# {'born': datetime.datetime(1998, 10, 30, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Kylin Hill', 'RB') to dictionary
# {'born': datetime.datetime(1998, 8, 18, 0, 0), 'draft': 256, 'pos': 'RB'}
# Added ('Tommy Hudson', 'TE') to dictionary
# {'born': datetime.datetime(1997, 2, 22, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Mike Strachan', 'WR') to dictionary
# {'born': datetime.datetime(1997, 8, 13, 0, 0), 'draft': 229, 'pos': 'WR'}
# Added ('Cody White', 'WR') to dictionary
# {'born': datetime.datetime(1998, 11, 28, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Seth Williams', 'WR') to dictionary
# {'born': datetime.datetime(2000, 4, 10, 0, 0), 'draft': 219, 'pos': 'WR'}
# Added ('Shane Zylstra', 'TE') to dictionary
# {'born': datetime.datetime(1996, 11, 16, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Ian Book', 'QB') to dictionary
# {'born': datetime.datetime(1998, 3, 30, 0, 0), 'draft': 133, 'pos': 'QB'}
# Added ('Davion Davis', 'WR') to dictionary
# {'born': datetime.datetime(1996, 10, 23, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Dazz Newsome', 'WR') to dictionary
# {'born': datetime.datetime(1999, 5, 15, 0, 0), 'draft': 221, 'pos': 'WR'}
# Added ('Adam Prentice', 'RB') to dictionary
# {'born': datetime.datetime(1997, 1, 16, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Trey Ragas', 'RB') to dictionary
# {'born': datetime.datetime(1996, 11, 7, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('David Sills', 'WR') to dictionary
# {'born': datetime.datetime(1996, 5, 29, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jack Stoll', 'TE') to dictionary
# {'born': datetime.datetime(1998, 1, 28, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Tylan Wallace', 'WR') to dictionary
# {'born': datetime.datetime(1999, 5, 13, 0, 0), 'draft': 131, 'pos': 'WR'}
# Added ('Mitchell Wilcox', 'TE') to dictionary
# {'born': datetime.datetime(1996, 11, 7, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Tarik Black', 'WR') to dictionary
# {'born': datetime.datetime(1998, 2, 10, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Gary Brightwell', 'RB') to dictionary
# {'born': datetime.datetime(1999, 2, 28, 0, 0), 'draft': 196, 'pos': 'RB'}
# Added ('Damarea Crockett', 'RB') to dictionary
# {'born': datetime.datetime(1997, 12, 22, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Frank Darby', 'WR') to dictionary
# {'born': datetime.datetime(1997, 9, 8, 0, 0), 'draft': 187, 'pos': 'WR'}
# Added ('Sam Ehlinger', 'QB') to dictionary
# {'born': datetime.datetime(1998, 9, 30, 0, 0), 'draft': 218, 'pos': 'QB'}
# Added ('Jake Funk', 'RB') to dictionary
# {'born': datetime.datetime(1998, 1, 11, 0, 0), 'draft': 233, 'pos': 'RB'}
# Added ('Brycen Hopkins', 'TE') to dictionary
# {'born': datetime.datetime(1997, 3, 27, 0, 0), 'draft': 136, 'pos': 'TE'}
# Added ('Hunter Long', 'TE') to dictionary
# {'born': datetime.datetime(1998, 8, 19, 0, 0), 'draft': 81, 'pos': 'TE'}
# Added ('Kirk Merritt', 'WR') to dictionary
# {'born': datetime.datetime(1997, 1, 5, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jacques Patrick', 'RB') to dictionary
# {'born': datetime.datetime(1997, 1, 7, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Kevin Rader', 'TE') to dictionary
# {'born': datetime.datetime(1995, 4, 26, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Mekhi Sargent', 'RB') to dictionary
# {'born': datetime.datetime(1997, 10, 8, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('C.J. Saunders', 'WR') to dictionary
# {'born': datetime.datetime(1996, 9, 15, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Easop Winston', 'WR') to dictionary
# {'born': datetime.datetime(1996, 12, 17, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Ethan Wolf', 'TE') to dictionary
# {'born': datetime.datetime(1995, 11, 7, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Josh Adams', '') to dictionary
# {'born': datetime.datetime(1996, 10, 29, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Geronimo Allison', '') to dictionary
# {'born': datetime.datetime(1994, 1, 18, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Devin Asiasi', '') to dictionary
# {'born': datetime.datetime(1997, 8, 14, 0, 0), 'draft': 91, 'pos': 'TE'}
# Added ('Marcell Ateman', '') to dictionary
# {'born': datetime.datetime(1994, 9, 16, 0, 0), 'draft': 228, 'pos': 'WR'}
# Added ('Tutu Atwell', '') to dictionary
# {'born': datetime.datetime(1999, 10, 7, 0, 0), 'draft': 57, 'pos': 'WR'}
# Added ('Alex Bachman', 'WR') to dictionary
# {'born': datetime.datetime(1996, 5, 29, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Kurt Benkert', 'QB') to dictionary
# {'born': datetime.datetime(1995, 7, 17, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('John Brown', '') to dictionary
# {'born': datetime.datetime(1990, 4, 3, 0, 0), 'draft': 91, 'pos': 'WR'}
# Added ('Lawrence Cager', '') to dictionary
# {'born': datetime.datetime(1997, 8, 20, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Tyrie Cleveland', '') to dictionary
# {'born': datetime.datetime(1997, 9, 20, 0, 0), 'draft': 252, 'pos': 'WR'}
# Added ('Nathan Cottrell', 'RB') to dictionary
# {'born': datetime.datetime(1996, 8, 2, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Connor Davis', '') to dictionary
# {'born': datetime.datetime(1994, 10, 20, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Jeff Driskel', '') to dictionary
# {'born': datetime.datetime(1993, 4, 23, 0, 0), 'draft': 207, 'pos': 'QB'}
# Added ('Ben Ellefson', '') to dictionary
# {'born': datetime.datetime(1996, 9, 1, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Simi Fehoko', '') to dictionary
# {'born': datetime.datetime(1997, 11, 5, 0, 0), 'draft': 179, 'pos': 'WR'}
# Added ('Maurice Ffrench', 'WR') to dictionary
# {'born': datetime.datetime(1998, 1, 1, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Antonio Gandy-Golden', '') to dictionary
# {'born': datetime.datetime(1998, 4, 11, 0, 0), 'draft': 142, 'pos': 'WR'}
# Added ("De'Michael Harris", '') to dictionary
# {'born': datetime.datetime(1998, 7, 12, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jacob Harris', '') to dictionary
# {'born': datetime.datetime(1997, 4, 16, 0, 0), 'draft': 141, 'pos': 'TE'}
# Added ('Daniel Helm', 'TE') to dictionary
# {'born': datetime.datetime(1995, 4, 20, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('John Hightower', '') to dictionary
# {'born': datetime.datetime(1996, 5, 31, 0, 0), 'draft': 168, 'pos': 'WR'}
# Added ('Brian Hill', '') to dictionary
# {'born': datetime.datetime(1995, 11, 9, 0, 0), 'draft': 156, 'pos': 'RB'}
# Added ('Kevin Hogan', '') to dictionary
# {'born': datetime.datetime(1992, 10, 20, 0, 0), 'draft': 162, 'pos': 'QB'}
# Added ('Tanner Hudson', '') to dictionary
# {'born': datetime.datetime(1994, 11, 12, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Ryan Izzo', '') to dictionary
# {'born': datetime.datetime(1995, 12, 21, 0, 0), 'draft': 250, 'pos': 'TE'}
# Added ('Kerryon Johnson', '') to dictionary
# {'born': datetime.datetime(1997, 6, 30, 0, 0), 'draft': 43, 'pos': 'RB'}
# Added ('KeeSean Johnson', '') to dictionary
# {'born': datetime.datetime(1996, 10, 9, 0, 0), 'draft': 174, 'pos': 'WR'}
# Added ('Tyler Mabry', '') to dictionary
# {'born': datetime.datetime(1996, 11, 21, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Nate McCrary', 'RB') to dictionary
# {'born': datetime.datetime(1999, 4, 9, 0, 0), 'draft': None, 'pos': None}
# Added ('Codey McElroy', '') to dictionary
# {'born': datetime.datetime(1992, 12, 13, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Kellen Mond', 'QB') to dictionary
# {'born': datetime.datetime(1999, 6, 22, 0, 0), 'draft': 66, 'pos': 'QB'}
# Added ('Artavis Pierce', '') to dictionary
# {'born': datetime.datetime(1996, 5, 17, 0, 0), 'draft': None, 'pos': 'RB'}
# Added ('Giovanni Ricci', '') to dictionary
# {'born': datetime.datetime(1996, 10, 16, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Jordan Scarlett', '') to dictionary
# {'born': datetime.datetime(1996, 2, 9, 0, 0), 'draft': 154, 'pos': 'RB'}
# Added ('Steven Sims', '') to dictionary
# {'born': datetime.datetime(1997, 3, 31, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Devin Smith', '') to dictionary
# {'born': datetime.datetime(1992, 3, 3, 0, 0), 'draft': 37, 'pos': 'WR'}
# Added ('Vyncint Smith', '') to dictionary
# {'born': datetime.datetime(1996, 6, 9, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Colin Thompson', '') to dictionary
# {'born': datetime.datetime(1993, 12, 15, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Cody Thompson', '') to dictionary
# {'born': datetime.datetime(1996, 1, 11, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Jordan Veasy', '') to dictionary
# {'born': datetime.datetime(1995, 6, 23, 0, 0), 'draft': None, 'pos': 'WR'}
# Added ('Kahale Warring', '') to dictionary
# {'born': datetime.datetime(1997, 3, 23, 0, 0), 'draft': 86, 'pos': 'TE'}
# Added ('Justin Watson', '') to dictionary
# {'born': datetime.datetime(1996, 4, 4, 0, 0), 'draft': 144, 'pos': 'WR'}
# Added ('Davis Webb', 'QB') to dictionary
# {'born': datetime.datetime(1995, 1, 22, 0, 0), 'draft': 87, 'pos': 'QB'}
# Added ('David Wells', '') to dictionary
# {'born': datetime.datetime(1995, 5, 2, 0, 0), 'draft': None, 'pos': 'TE'}
# Added ('Jordan Wilkins', '') to dictionary
# {'born': datetime.datetime(1994, 7, 18, 0, 0), 'draft': 169, 'pos': 'RB'}
# Added ('Jacob Eason', 'QB') to dictionary
# {'born': datetime.datetime(1997, 11, 17, 0, 0), 'draft': 122, 'pos': 'QB'}
# Added ('Feleipe Franks', 'QB') to dictionary
# {'born': datetime.datetime(1997, 12, 22, 0, 0), 'draft': None, 'pos': 'QB'}
# Added ('Racey McMath', 'WR') to dictionary
# {'born': datetime.datetime(1999, 6, 14, 0, 0), 'draft': 205, 'pos': 'WR'}
# Added ('Travis Benjamin', '') to dictionary
# {'born': datetime.datetime(1989, 12, 29, 0, 0), 'draft': 100, 'pos': 'WR'}

# %%
def import_pts_data(link = PFR_LINK):
    fpts_dict = {}
    for i in range(2013, 2022):
        use_link = link.format(yr = i)
        print(use_link)
        page = requests.get(use_link)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
            
        table = soup.find_all('table', id = 'fantasy')
        df = pd.read_html(str(table), flavor = 'html5lib')[0]
        df.columns = df.columns.get_level_values(1)
        df['Year'] = i
        fpts_dict[i] = df
    return fpts_dict

fpts_dict = import_pts_data(PFR_LINK)

with open('data/pfr_player_pts.p', 'wb') as handle:
    pickle.dump(fpts_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# https://www.pro-football-reference.com/years/2013/fantasy.htm
# https://www.pro-football-reference.com/years/2014/fantasy.htm
# https://www.pro-football-reference.com/years/2015/fantasy.htm
# https://www.pro-football-reference.com/years/2016/fantasy.htm
# https://www.pro-football-reference.com/years/2017/fantasy.htm
# https://www.pro-football-reference.com/years/2018/fantasy.htm
# https://www.pro-football-reference.com/years/2019/fantasy.htm
# https://www.pro-football-reference.com/years/2020/fantasy.htm
# https://www.pro-football-reference.com/years/2021/fantasy.htm

# %%
checkColNames(fpts_dict)

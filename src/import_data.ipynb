# %%
import re
import pickle
import requests
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Dictionary mapping fantasydata.com team abbreviations to pro-football-reference team abbreviations
adp_to_pfr = {'ARI':'ARI','ATL':'ATL','BAL':'BAL','BUF':'BUF','CAR':'CAR',
                'CHI':'CHI','CIN':'CIN','CLE':'CLE','DAL':'DAL','DEN':'DEN',
                'DET':'DET','GB':'GNB','HOU':'HOU','IND':'IND','JAX':'JAX',
                'KC':'KAN','LAC':'LAC','LAR':'LAR','LV':'LVR','MIA':'MIA',
                'MIN':'MIN','NO':'NOR','NE':'NWE','NYG':'NYG','NYJ':'NYJ',
                'PHI':'PHI','PIT':'PIT','SEA':'SEA','SF':'SFO','TB':'TAM',
                'TEN':'TEN','WAS':'WAS'}

# %%
# Source: https://fantasydata.com/nfl/adp - PPR
def import_adp_data(files_loc = '../data/historical_adp/'):
    df_dict = {}
    for i in range(2014, 2023):
        cols = ["Name", "Team", "Position", "PositionRank", "AverageDraftPositionPPR"]
        tmp= pd.read_csv(f'{files_loc}ppr-adp-{i}.csv',
                        usecols = cols)
        tmp['Year'] = i
        df_dict[i] = tmp
    return df_dict

def prep_adp_df(adp_data, adp_to_pfr):
    # Limit to only top 200 in ADP per year

    # 1. Concat
    adp_df = pd.concat(adp_data.values())
    # 2. Re-order columns
    adp_df = adp_df[['Name', 'Year', 'Team', 'Position', 'PositionRank', 'AverageDraftPositionPPR']]

    # 3. Get position rank as a number
    adp_df['PositionRank'] = adp_df['PositionRank'].str.extract('(\d+)')[0]
    
    # 4. Reset index
    adp_df.reset_index(inplace=True)
    adp_df.drop('index', axis = 1, inplace=True)
    # adp_df = adp_df.join(pd.get_dummies(adp_df['Position']))

    # 5. Remove III's from end of names
    adp_df['Name'] = adp_df['Name'].str.replace('([I ]+$)', '',regex= True)
    adp_df['Name'] = adp_df['Name'].str.replace('CJ ', 'C.J. ')
    adp_df['Name'] = adp_df['Name'].str.replace('DJ ', 'D.J. ')
    adp_df['Name'] = adp_df['Name'].str.replace('DK ', 'D.K. ')
    adp_df['Name'] = adp_df['Name'].str.replace('Steve Smith', 'Steve Smith Sr.')
    adp_df['Name'] = adp_df['Name'].str.replace('Marvin Jones Jr.', 'Marvin Jones', regex = False)
    adp_df['Name'] = adp_df['Name'].str.replace('Darrell Henderson Jr.', 'Darrell Henderson', regex = False)
    adp_df['Name'] = adp_df['Name'].str.replace('Gabe Davis', 'Gabriel Davis')
    # adp_df = adp_df[adp_df['AverageDraftPositionPPR'] < 173].copy()
    # Changing to 170 to have consistent cutoff for position-based regression

    # 6. Limit to standard, relevant fantas positions
    adp_df = adp_df[adp_df['Position'].isin(['RB','WR','QB','WR','TE'])]

    # 7. Update team names for those teams that have moved in last 10 years
    adp_df['Team'] = adp_df['Team'].replace(adp_to_pfr) 
    adp_df.loc[(adp_df['Team'] == 'LVR') & (adp_df['Year'] <= 2019),'Team'] = 'OAK'
    adp_df.loc[(adp_df['Team'] == 'LAC') & (adp_df['Year'] <= 2016),'Team'] = 'SDG'
    adp_df.loc[(adp_df['Team'] == 'LAR') & (adp_df['Year'] <= 2015),'Team'] = 'STL'

    adp_df.loc[adp_df['Name'].str.contains('Jordan Matthews'), 'Position'] = "WR"
    adp_df.loc[adp_df['Name'].str.contains('Funchess'), 'Position'] = "WR"
    adp_df.loc[adp_df['Name'].str.contains('Trubisky'), 'Name'] = "Mitchell Trubisky"
    adp_df.loc[adp_df['Name'].str.contains('Minshew'), 'Name'] = 'Gardner Minshew II'
    adp_df.loc[adp_df['Name'].str.contains('Chark'), 'Name'] = 'DJ Chark'
    adp_df.loc[adp_df['Name'].str.contains('Robert Griffin'), 'Name'] = 'Robert Griffin III'
    adp_df.loc[adp_df['Name'].str.contains('Willie Snead'), 'Name'] = 'Willie Snead'
    adp_df.loc[adp_df['Name'].str.contains('William Fuller'), 'Name'] = 'Will Fuller'
    adp_df.loc[adp_df['Name'].str.contains('Ronald Jones'), 'Name'] = 'Ronald Jones II'
    adp_df.loc[adp_df['Name'].str.contains('Benjamin Watson'), 'Name'] = 'Ben Watson'
    adp_df.loc[adp_df['Name'].str.contains('Rob Kelley'), 'Name'] = 'Robert Kelley'
    adp_df.loc[adp_df['Name'].str.contains('Henry Ruggs'), 'Name'] = 'Henry Ruggs III'
    adp_df.loc[adp_df['Name'].str.contains('Kenneth Walker'), 'Name'] = 'Kenneth Walker III'
    return adp_df

# %%
df_dict = import_adp_data()
adp_df = prep_adp_df(df_dict, adp_to_pfr)

with open('../data/created/adp_info.p', 'wb') as handle:
    pickle.dump(adp_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Check col names same across years
def checkColNames(df_dict):
    a = None
    for k, v in df_dict.items():
        if a is None:
            a = list(v.columns)
        if list(v.columns) != a:
            print('There are some years where df columns have different names')

# Check Teams are correct
def checkTeamNames(df):
    test = df[['Team','Year']].drop_duplicates().sort_values(['Year','Team'])
    a = test.groupby(['Team'], as_index = False).min()[['Team','Year']]
    b = test.groupby(['Team'], as_index = False).max()[['Team','Year']]
    c = a.merge(b, on = 'Team')
    print(c[(c['Year_y'] - c['Year_x']) < 9])

checkColNames(df_dict)
checkTeamNames(adp_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kniu91/Documents/kevins_folders/Grad Schools/UChicago MPCS/Fall 2022/fantasyProjections/src/import_data.ipynb Cell 5 in <cell line: 18>()
#      <a href='vscode-notebook-cell:/Users/kniu91/Documents/kevins_folders/Grad%20Schools/UChicago%20MPCS/Fall%202022/fantasyProjections/src/import_data.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a>     c = a.merge(b, on = 'Team')
#      <a href='vscode-notebook-cell:/Users/kniu91/Documents/kevins_folders/Grad%20Schools/UChicago%20MPCS/Fall%202022/fantasyProjections/src/import_data.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a>     print(c[(c['Year_y'] - c['Year_x']) < 8])
# ---> <a href='vscode-notebook-cell:/Users/kniu91/Documents/kevins_folders/Grad%20Schools/UChicago%20MPCS/Fall%202022/fantasyProjections/src/import_data.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> checkColNames(df_dict)
#      <a href='vscode-notebook-cell:/Users/kniu91/Documents/kevins_folders/Grad%20Schools/UChicago%20MPCS/Fall%202022/fantasyProjections/src/import_data.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a> checkTeamNames(adp_df)
#
# NameError: name 'df_dict' is not defined

# %%
PFR_LINK = 'https://www.pro-football-reference.com/years/{yr}/fantasy.htm'

def player_info_from_link(link):
    info_dict = {'born' : None,
                    'draft': None,
                    'pos' : None}

    page = requests.get(link)
    if page.status_code == 200:
        soup = BeautifulSoup(page.content, 'html.parser')
    player_info  = soup.find_all('p')
    
    for info in player_info:
        if len(info.find_all('strong', text = 'Position')) > 0 :
            info_dict['pos'] = info.text.split(' ')[1].strip()[:2]
        if len(info.find_all('strong', text = 'Born:')) > 0 :
            dob = (info.text.replace('\n', ' ').replace('\xa0', ' '))
            dob = re.search('\w+\s\d{1,2},\s\d{4}', dob).group(0)
            info_dict['born'] = datetime.strptime(dob, '%B %d, %Y')
        if len(info.find_all('strong', text = 'Draft')) > 0:
            draft_info = info.text
            draft_pos = re.search('\([0-9]*', draft_info)
            draft_year = re.search(r'(\d{4}) NFL Draft', draft_info)
            try:
                info_dict['draft'] = int(draft_pos.group(0)[1:])
                info_dict['drat_year'] = int(draft_year.group(1))
            except:
                pass

    return info_dict
        
# ID players by uniqe (name, position)
# Add to a dictionary containing their
    # 1. Birthdates
    # 2. NFL Draft Position
    # 3. Position
                    
def get_player_info(link = PFR_LINK):
    player_dict = {}
    for i in range(2013, 2022):
        use_link = link.format(yr = i)
        print(use_link)
        
        page = requests.get(use_link)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
        table = soup.find_all('table', id = 'fantasy')
        players = table[0].find_all('tr')
        
        for player in players:
            atag = player.find_all('a')
            if len(atag) > 0:
                table_cols = player.find_all('td', class_="right")
                name = atag[0].text 
                position = table_cols[0].text
                if (name, position) not in player_dict:
                    print(f"Added {(name, position)} to dictionary")
                    player_link = 'https://www.pro-football-reference.com' + atag[0]['href']
                    info = player_info_from_link(player_link)
                    print(info)
                    player_dict[name, position] = info
    return player_dict
            
player_dict = get_player_info()

# %%
def getDrafteeInfo(player_dict, year = 2022):
    link = f"https://www.pro-football-reference.com/years/{year}/draft.htm"
    page = requests.get(link)
    if page.status_code == 200:
        soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find_all('table', id = 'drafts')
    players = table[0].find_all('tr')
    for player in players:
        res = player.find_all('a')
        if len(res) > 0:
            a = player.find_all('td')
            name = res[1].text 
            position = a[3].text
            if name == 'North Dakota St.':
                continue
            print(name, position)
            if (name, position) not in player_dict:
                print(f"Added {(name, position)} to dictionary")
                player_link = 'https://www.pro-football-reference.com' + res[1]['href']
                info = player_info_from_link(player_link)

                player_dict[(name, position)] = info
    return player_dict

# with open('../data/pfr_player_info.p', 'rb') as handle:
#     player_dict = pickle.load(handle)
# player_dict = getDrafteeInfo(player_dict)
# player_dict = getDrafteeInfo(player_dict, 2021)

# with open('../data/created/pfr_player_info.p', 'wb') as handle:
#     pickle.dump(player_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trevor Lawrence QB
# Zach Wilson QB
# Trey Lance QB
# Kyle Pitts TE
# Ja'Marr Chase WR
# Jaylen Waddle WR
# Penei Sewell OL
# Added ('Penei Sewell', 'OL') to dictionary
# Jaycee Horn DB
# Added ('Jaycee Horn', 'DB') to dictionary
# Patrick Surtain II DB
# Added ('Patrick Surtain II', 'DB') to dictionary
# DeVonta Smith WR
# Justin Fields QB
# Micah Parsons LB
# Added ('Micah Parsons', 'LB') to dictionary
# Rashawn Slater OL
# Added ('Rashawn Slater', 'OL') to dictionary
# Alijah Vera-Tucker OL
# Added ('Alijah Vera-Tucker', 'OL') to dictionary
# Mac Jones QB
# Zaven Collins LB
# Added ('Zaven Collins', 'LB') to dictionary
# Alex Leatherwood OL
# Added ('Alex Leatherwood', 'OL') to dictionary
# Jaelan Phillips DL
# Added ('Jaelan Phillips', 'DL') to dictionary
# Jamin Davis LB
# Added ('Jamin Davis', 'LB') to dictionary
# Kadarius Toney WR
# Kwity Paye DL
# Added ('Kwity Paye', 'DL') to dictionary
# Caleb Farley DB
# Added ('Caleb Farley', 'DB') to dictionary
# Christian Darrisaw OL
# Added ('Christian Darrisaw', 'OL') to dictionary
# Najee Harris RB
# Travis Etienne RB
# Added ('Travis Etienne', 'RB') to dictionary
# Greg Newsome II DB
# Added ('Greg Newsome II', 'DB') to dictionary
# Rashod Bateman WR
# Payton Turner DE
# Added ('Payton Turner', 'DE') to dictionary
# Eric Stokes DB
# Added ('Eric Stokes', 'DB') to dictionary
# Gregory Rousseau DL
# Added ('Gregory Rousseau', 'DL') to dictionary
# Odafe Oweh  DE
# Added ('Odafe Oweh ', 'DE') to dictionary
# Joe Tryon-Shoyinka OLB
# Added ('Joe Tryon-Shoyinka', 'OLB') to dictionary
# Tyson Campbell DB
# Added ('Tyson Campbell', 'DB') to dictionary
# Elijah Moore WR
# Javonte Williams RB
# Jevon Holland S
# Added ('Jevon Holland', 'S') to dictionary
# Landon Dickerson OL
# Added ('Landon Dickerson', 'OL') to dictionary
# Christian Barmore DL
# Added ('Christian Barmore', 'DL') to dictionary
# Teven Jenkins OL
# Added ('Teven Jenkins', 'OL') to dictionary
# Richie Grant DB
# Added ('Richie Grant', 'DB') to dictionary
# Levi Onwuzurike DL
# Added ('Levi Onwuzurike', 'DL') to dictionary
# Liam Eichenberg OL
# Added ('Liam Eichenberg', 'OL') to dictionary
# Trevon Moehrig S
# Added ('Trevon Moehrig', 'S') to dictionary
# Kelvin Joseph DB
# Added ('Kelvin Joseph', 'DB') to dictionary
# Walker Little T
# Added ('Walker Little', 'T') to dictionary
# Jackson Carman T
# Added ('Jackson Carman', 'T') to dictionary
# Asante Samuel Jr. DB
# Added ('Asante Samuel Jr.', 'DB') to dictionary
# Aaron Banks OL
# Added ('Aaron Banks', 'OL') to dictionary
# Rondale Moore WR
# Azeez Ojulari OLB
# Added ('Azeez Ojulari', 'OLB') to dictionary
# Samuel Cosmi OL
# Added ('Samuel Cosmi', 'OL') to dictionary
# Jeremiah Owusu-Koramoah LB
# Added ('Jeremiah Owusu-Koramoah', 'LB') to dictionary
# Dillon Radunz T
# Added ('Dillon Radunz', 'T') to dictionary
# Dayo Odeyingbo DL
# Added ('Dayo Odeyingbo', 'DL') to dictionary
# Pat Freiermuth TE
# D'Wayne Eskridge WR
# Tutu Atwell WR
# Added ('Tutu Atwell', 'WR') to dictionary
# Nick Bolton LB
# Added ('Nick Bolton', 'LB') to dictionary
# Terrace Marshall Jr. WR
# Pete Werner LB
# Added ('Pete Werner', 'LB') to dictionary
# Boogie Basham DL
# Added ('Boogie Basham', 'DL') to dictionary
# Josh Myers C
# Added ('Josh Myers', 'C') to dictionary
# Creed Humphrey OL
# Added ('Creed Humphrey', 'OL') to dictionary
# Kyle Trask QB
# Added ('Kyle Trask', 'QB') to dictionary
# Andre Cisco DB
# Added ('Andre Cisco', 'DB') to dictionary
# Kellen Mond QB
# Davis Mills QB
# Jalen Mayfield OL
# Added ('Jalen Mayfield', 'OL') to dictionary
# Joseph Ossai LB
# Added ('Joseph Ossai', 'LB') to dictionary
# Brady Christensen OL
# Added ('Brady Christensen', 'OL') to dictionary
# Aaron Robinson DB
# Added ('Aaron Robinson', 'DB') to dictionary
# Alim McNeill DT
# Added ('Alim McNeill', 'DT') to dictionary
# Milton Williams DL
# Added ('Milton Williams', 'DL') to dictionary
# Benjamin St-Juste DB
# Added ('Benjamin St-Juste', 'DB') to dictionary
# Osa Odighizuwa DL
# Added ('Osa Odighizuwa', 'DL') to dictionary
# Paulson Adebo CB
# Added ('Paulson Adebo', 'CB') to dictionary
# Josh Palmer WR
# Chazz Surratt LB
# Added ('Chazz Surratt', 'LB') to dictionary
# Malcolm Koonce DE
# Added ('Malcolm Koonce', 'DE') to dictionary
# Divine Deablo DB
# Added ('Divine Deablo', 'DB') to dictionary
# Hunter Long TE
# Dyami Brown WR
# Tommy Tremble TE
# Chauncey Golston DL
# Added ('Chauncey Golston', 'DL') to dictionary
# Amari Rodgers WR
# Wyatt Davis OL
# Added ('Wyatt Davis', 'OL') to dictionary
# Kendrick Green OL
# Added ('Kendrick Green', 'OL') to dictionary
# Trey Sermon RB
# Nico Collins WR
# Patrick Jones II DL
# Added ('Patrick Jones II', 'DL') to dictionary
# Anthony Schwartz WR
# Monty Rice LB
# Added ('Monty Rice', 'LB') to dictionary
# Spencer Brown OL
# Added ('Spencer Brown', 'OL') to dictionary
# Ben Cleveland OL
# Added ('Ben Cleveland', 'OL') to dictionary
# Robert Hainsey OL
# Added ('Robert Hainsey', 'OL') to dictionary
# Ronnie Perkins DE
# Added ('Ronnie Perkins', 'DE') to dictionary
# Tre' McKitty TE
# Quinn Meinerz C
# Added ('Quinn Meinerz', 'C') to dictionary
# Nahshon Wright DB
# Added ('Nahshon Wright', 'DB') to dictionary
# Elijah Molden DB
# Added ('Elijah Molden', 'DB') to dictionary
# Ifeatu Melifonwu DB
# Added ('Ifeatu Melifonwu', 'DB') to dictionary
# Ambry Thomas DB
# Added ('Ambry Thomas', 'DB') to dictionary
# Ernest Jones LB
# Added ('Ernest Jones', 'LB') to dictionary
# Brandon Stephens CB
# Added ('Brandon Stephens', 'CB') to dictionary
# Baron Browning LB
# Added ('Baron Browning', 'LB') to dictionary
# Jay Tufele DL
# Added ('Jay Tufele', 'DL') to dictionary
# Michael Carter RB
# Darren Hall CB
# Added ('Darren Hall', 'CB') to dictionary
# Dez Fitzpatrick WR
# James Hudson OL
# Added ('James Hudson', 'OL') to dictionary
# Cameron Sample DE
# Added ('Cameron Sample', 'DE') to dictionary
# Amon-Ra St. Brown WR
# Derrick Barnes DE
# Added ('Derrick Barnes', 'DE') to dictionary
# Drew Dalman C
# Added ('Drew Dalman', 'C') to dictionary
# Jabril Cox LB
# Added ('Jabril Cox', 'LB') to dictionary
# Elerson Smith DL
# Added ('Elerson Smith', 'DL') to dictionary
# Bobby Brown DL
# Added ('Bobby Brown', 'DL') to dictionary
# Chris Rumph DE
# Added ('Chris Rumph', 'DE') to dictionary
# Kene Nwangwu RB
# Rhamondre Stevenson RB
# Jordan Smith OLB
# Added ('Jordan Smith', 'OLB') to dictionary
# Tyler Shelvin DT
# Added ('Tyler Shelvin', 'DT') to dictionary
# Zech McPhearson DB
# Added ('Zech McPhearson', 'DB') to dictionary
# John Bates TE
# Camryn Bynum CB
# Added ('Camryn Bynum', 'CB') to dictionary
# Chuba Hubbard RB
# Kylen Granson TE
# Dan Moore OL
# Added ('Dan Moore', 'OL') to dictionary
# Jaelon Darden WR
# Robert Rochell DB
# Added ('Robert Rochell', 'DB') to dictionary
# Tylan Wallace WR
# Tommy Togiai DT
# Added ('Tommy Togiai', 'DT') to dictionary
# Ian Book QB
# Janarius Robinson DE
# Added ('Janarius Robinson', 'DE') to dictionary
# Rashad Weaver DL
# Added ('Rashad Weaver', 'DL') to dictionary
# Marco Wilson CB
# Added ('Marco Wilson', 'CB') to dictionary
# Tre Brown CB
# Added ('Tre Brown', 'CB') to dictionary
# Josh Ball OL
# Added ('Josh Ball', 'OL') to dictionary
# D'Ante Smith T
# Added ("D'Ante Smith", 'T') to dictionary
# Buddy Johnson LB
# Added ('Buddy Johnson', 'LB') to dictionary
# Jacob Harris WR
# Added ('Jacob Harris', 'WR') to dictionary
# Royce Newman G
# Added ('Royce Newman', 'G') to dictionary
# Tyree Gillespie S
# Added ('Tyree Gillespie', 'S') to dictionary
# Joshua Kaindoh DE
# Added ('Joshua Kaindoh', 'DE') to dictionary
# Luke Farrell TE
# Jamien Sherwood DB
# Added ('Jamien Sherwood', 'DB') to dictionary
# Brevin Jordan TE
# Ta'Quon Graham DL
# Added ("Ta'Quon Graham", 'DL') to dictionary
# Evan McPherson K
# Added ('Evan McPherson', 'K') to dictionary
# Kenneth Gainwell RB
# Larry Borom OL
# Added ('Larry Borom', 'OL') to dictionary
# Caden Sterns DB
# Added ('Caden Sterns', 'DB') to dictionary
# Tony Fields LB
# Added ('Tony Fields', 'LB') to dictionary
# Michael Carter S
# Added ('Michael Carter', 'S') to dictionary
# Jaylon Moore T
# Added ('Jaylon Moore', 'T') to dictionary
# Isaiahh Loudermilk DE
# Added ('Isaiahh Loudermilk', 'DE') to dictionary
# Ihmir Smith-Marsette WR
# Daviyon Nixon DT
# Added ('Daviyon Nixon', 'DT') to dictionary
# Brenden Jaimes OL
# Added ('Brenden Jaimes', 'OL') to dictionary
# Shaun Wade CB
# Added ('Shaun Wade', 'CB') to dictionary
# Tommy Doyle OL
# Added ('Tommy Doyle', 'OL') to dictionary
# Noah Gray TE
# Darrick Forrest S
# Added ('Darrick Forrest', 'S') to dictionary
# Jamar Johnson DB
# Added ('Jamar Johnson', 'DB') to dictionary
# Shawn Davis DB
# Added ('Shawn Davis', 'DB') to dictionary
# Keith Taylor DB
# Added ('Keith Taylor', 'DB') to dictionary
# Nate Hobbs CB
# Added ('Nate Hobbs', 'CB') to dictionary
# Zach Davidson TE
# Added ('Zach Davidson', 'TE') to dictionary
# Richard LeCounte DB
# Added ('Richard LeCounte', 'DB') to dictionary
# Garret Wallow LB
# Added ('Garret Wallow', 'LB') to dictionary
# Daelin Hayes DL
# Added ('Daelin Hayes', 'DL') to dictionary
# Deommodore Lenoir CB
# Added ('Deommodore Lenoir', 'CB') to dictionary
# Tedarrell Slaton DL
# Added ('Tedarrell Slaton', 'DL') to dictionary
# Earnest Brown IV DE
# Added ('Earnest Brown IV', 'DE') to dictionary
# Jason Pinnock CB
# Added ('Jason Pinnock', 'CB') to dictionary
# K.J. Britt LB
# Added ('K.J. Britt', 'LB') to dictionary
# Cameron McGrone LB
# Added ('Cameron McGrone', 'LB') to dictionary
# Shemar Jean-Charles DB
# Added ('Shemar Jean-Charles', 'DB') to dictionary
# Simi Fehoko WR
# Added ('Simi Fehoko', 'WR') to dictionary
# Talanoa Hufanga S
# Added ('Talanoa Hufanga', 'S') to dictionary
# Cornell Powell WR
# Added ('Cornell Powell', 'WR') to dictionary
# Adetokunbo Ogundeji DL
# Added ('Adetokunbo Ogundeji', 'DL') to dictionary
# Avery Williams CB
# Added ('Avery Williams', 'CB') to dictionary
# Ben Mason FB
# Added ('Ben Mason', 'FB') to dictionary
# Nick Niemann LB
# Added ('Nick Niemann', 'LB') to dictionary
# Hamsah Nasirildeen DB
# Added ('Hamsah Nasirildeen', 'DB') to dictionary
# Frank Darby WR
# Joshuah Bledsoe S
# Added ('Joshuah Bledsoe', 'S') to dictionary
# Marlon Tuipulotu DL
# Added ('Marlon Tuipulotu', 'DL') to dictionary
# Trey Hill OL
# Added ('Trey Hill', 'OL') to dictionary
# Tarron Jackson DE
# Added ('Tarron Jackson', 'DE') to dictionary
# Quinton Bohanna DT
# Added ('Quinton Bohanna', 'DT') to dictionary
# Deonte Brown OL
# Added ('Deonte Brown', 'OL') to dictionary
# Elijah Mitchell RB
# Roy Lopez DL
# Added ('Roy Lopez', 'DL') to dictionary
# Gary Brightwell RB
# William Sherman OL
# Added ('William Sherman', 'OL') to dictionary
# Larry Rountree RB
# Jaylen Twyman DL
# Added ('Jaylen Twyman', 'DL') to dictionary
# Brandin Echols CB
# Added ('Brandin Echols', 'CB') to dictionary
# Rodarius Williams CB
# Added ('Rodarius Williams', 'CB') to dictionary
# Chris Evans RB
# Marquez Stevenson WR
# Added ('Marquez Stevenson', 'WR') to dictionary
# Shi Smith WR
# Racey McMath WR
# Landon Young T
# Added ('Landon Young', 'T') to dictionary
# Jonathan Marshall DL
# Added ('Jonathan Marshall', 'DL') to dictionary
# Stone Forsythe OL
# Added ('Stone Forsythe', 'OL') to dictionary
# Jalen Camp WR
# Added ('Jalen Camp', 'WR') to dictionary
# Victor Dimukeje DE
# Added ('Victor Dimukeje', 'DE') to dictionary
# Demetric Felton RB
# Damar Hamlin DB
# Added ('Damar Hamlin', 'DB') to dictionary
# Rachad Wildgoose CB
# Added ('Rachad Wildgoose', 'CB') to dictionary
# Cole Van Lanen OL
# Added ('Cole Van Lanen', 'OL') to dictionary
# Brady Breeze S
# Added ('Brady Breeze', 'S') to dictionary
# Quincy Roche DL
# Added ('Quincy Roche', 'DL') to dictionary
# Khalil Herbert RB
# Sam Ehlinger QB
# Seth Williams WR
# Isaiah McDuffie  LB
# Added ('Isaiah McDuffie ', 'LB') to dictionary
# Dazz Newsome WR
# Thomas Fletcher LS
# Added ('Thomas Fletcher', 'LS') to dictionary
# Tay Gowan DB
# Added ('Tay Gowan', 'DB') to dictionary
# JaCoby Stevens S
# Added ('JaCoby Stevens', 'S') to dictionary
# Camaron Cheeseman LS
# Added ('Camaron Cheeseman', 'LS') to dictionary
# Trey Smith OL
# Added ('Trey Smith', 'OL') to dictionary
# Israel Mukuamu DB
# Added ('Israel Mukuamu', 'DB') to dictionary
# Thomas Graham CB
# Added ('Thomas Graham', 'CB') to dictionary
# Mike Strachan WR
# Jimmy Morrissey OL
# Added ('Jimmy Morrissey', 'OL') to dictionary
# Larnel Coleman T
# Added ('Larnel Coleman', 'T') to dictionary
# Phil Hoskins DT
# Added ('Phil Hoskins', 'DT') to dictionary
# Jake Funk RB
# Patrick Johnson DE
# Added ('Patrick Johnson', 'DE') to dictionary
# Wyatt Hubert DE
# Added ('Wyatt Hubert', 'DE') to dictionary
# Jack Anderson OL
# Added ('Jack Anderson', 'OL') to dictionary
# Kary Vincent Jr. CB
# Added ('Kary Vincent Jr.', 'CB') to dictionary
# Matt Farniok G
# Added ('Matt Farniok', 'G') to dictionary
# Jonathon Cooper DE
# Added ('Jonathon Cooper', 'DE') to dictionary
# William Bradley-King OLB
# Added ('William Bradley-King', 'OLB') to dictionary
# Mark Webb DB
# Added ('Mark Webb', 'DB') to dictionary
# Tre Nixon WR
# Added ('Tre Nixon', 'WR') to dictionary
# James Wiggins S
# Added ('James Wiggins', 'S') to dictionary
# Gerrid Doaks RB
# Added ('Gerrid Doaks', 'RB') to dictionary
# Tre Norwood DB
# Added ('Tre Norwood', 'DB') to dictionary
# Shaka Toney DE
# Added ('Shaka Toney', 'DE') to dictionary
# Michal Menet OL
# Added ('Michal Menet', 'OL') to dictionary
# Will Fries OL
# Added ('Will Fries', 'OL') to dictionary
# Ben Skowronek WR
# Khyiris Tonga DL
# Added ('Khyiris Tonga', 'DL') to dictionary
# Chris Wilcox DB
# Added ('Chris Wilcox', 'DB') to dictionary
# Chris Garrett DE
# Added ('Chris Garrett', 'DE') to dictionary
# Marquiss Spencer DE
# Added ('Marquiss Spencer', 'DE') to dictionary
# Pressley Harvin III P
# Added ('Pressley Harvin III', 'P') to dictionary
# Kawaan Baker WR
# Added ('Kawaan Baker', 'WR') to dictionary
# Kylin Hill RB
# Jermar Jefferson RB
# Dax Milne WR
# Grant Stuard LB
# Added ('Grant Stuard', 'LB') to dictionary

# %%
def import_pts_data(link = PFR_LINK):
    fpts_dict = {}
    for i in range(2013, 2022):
        use_link = link.format(yr = i)
        print(use_link)
        page = requests.get(use_link)
        if page.status_code == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
            
        table = soup.find_all('table', id = 'fantasy')
        df = pd.read_html(str(table), flavor = 'html5lib')[0]
        df.columns = df.columns.get_level_values(1)
        df['Year'] = i
        fpts_dict[i] = df
    return fpts_dict

fpts_dict = import_pts_data(PFR_LINK)

with open('../data/created/pfr_player_pts.p', 'wb') as handle:
    pickle.dump(fpts_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# https://www.pro-football-reference.com/years/2013/fantasy.htm
# https://www.pro-football-reference.com/years/2014/fantasy.htm
# https://www.pro-football-reference.com/years/2015/fantasy.htm
# https://www.pro-football-reference.com/years/2016/fantasy.htm
# https://www.pro-football-reference.com/years/2017/fantasy.htm
# https://www.pro-football-reference.com/years/2018/fantasy.htm
# https://www.pro-football-reference.com/years/2019/fantasy.htm
# https://www.pro-football-reference.com/years/2020/fantasy.htm
# https://www.pro-football-reference.com/years/2021/fantasy.htm

# %%
checkColNames(fpts_dict)
